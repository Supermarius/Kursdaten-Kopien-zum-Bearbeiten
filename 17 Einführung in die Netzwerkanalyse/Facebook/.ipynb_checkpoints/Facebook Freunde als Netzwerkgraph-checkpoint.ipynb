# %% [markdown]
# # Facebook Freunde Scrapen
# - Eine super Datenquelle um Netzwerke zu verstehen sind die eigenen Freunde.
# - Diese lassen sich von Facebook scrapen, da Facebook natürlich keinen Export erlaubt - d'oh.

# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import json
import csv
import re

# %%
s = webdriver.Chrome('/usr/local/bin/chromedriver')

# %% [markdown]
# https://selenium-python.readthedocs.io/api.html#selenium.webdriver.remote.webdriver.WebDriver.find_element_by_link_text-

# %%
USERNAME = "makulatur@gmx.ch"
PASSWORD = "xxxxxxxxxxx"
MY_SLUG = "marius.huber.58"

# %%
def login(s):
    try:
        print("Logging into FB")
        s.get("http://facebook.com/login")
        s.find_element_by_id("email").send_keys(USERNAME)
        r = s.find_element_by_id("pass")
        r.send_keys(PASSWORD)
        r.send_keys(Keys.RETURN)
    except:
        print("Probably already logged in...")

# %%
def scrape_friends(s):
    login(s)
    #Scrape my friends
    s.get("https://www.facebook.com/%s/friends" % MY_SLUG)
    for i in range(30):
        print("scrolling...and...waiting..%s" % i)
        s.execute_script('window.scroll(0,100000);')
        time.sleep(1)
    # get html
    elem = s.find_element_by_xpath("//*")
    source_code = elem.get_attribute("outerHTML")
    soup = BeautifulSoup(source_code, 'lxml')
    friends = soup.select(".fcb a")
    print("Scraping {%s} friends" % len(friends))
    with open('friends.csv', mode='w') as myfile:
        mycsv = csv.writer(myfile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        mycsv.writerow(["Friend ID", "Friend Name"])
        for friend in friends:
          try:
            friend_name = friend.text.encode("ascii","ignore")
            friend_id = json.loads(friend["data-gt"])["engagement"]["eng_tid"].encode("ascii","ignore")
            mycsv.writerow([friend_id, friend_name])
          except:
            print("Problems obtaining %s" % friend)

# %%
scrape_friends(s)
# Out:
# Logging into FB
# scrolling...and...waiting..0
# scrolling...and...waiting..1
# scrolling...and...waiting..2
# scrolling...and...waiting..3
# scrolling...and...waiting..4
# scrolling...and...waiting..5
# scrolling...and...waiting..6
# scrolling...and...waiting..7
# scrolling...and...waiting..8
# scrolling...and...waiting..9
# scrolling...and...waiting..10
# scrolling...and...waiting..11
# scrolling...and...waiting..12
# scrolling...and...waiting..13
# scrolling...and...waiting..14
# scrolling...and...waiting..15
# scrolling...and...waiting..16
# scrolling...and...waiting..17
# scrolling...and...waiting..18
# scrolling...and...waiting..19
# scrolling...and...waiting..20
# scrolling...and...waiting..21
# scrolling...and...waiting..22
# scrolling...and...waiting..23
# scrolling...and...waiting..24
# scrolling...and...waiting..25
# scrolling...and...waiting..26
# scrolling...and...waiting..27
# scrolling...and...waiting..28
# scrolling...and...waiting..29
# Scraping {202} friends
# Problems obtaining <a ajaxify="/ajax/friends/inactive/dialog?id=100002310301732" href="#" rel="dialog" role="button">Pius Huber-Walser</a>
# Problems obtaining <a ajaxify="/ajax/friends/inactive/dialog?id=549449148" href="#" rel="dialog" role="button">Thomas Meyer</a>
# Problems obtaining <a ajaxify="/ajax/friends/inactive/dialog?id=100002159187980" href="#" rel="dialog" role="button">Derrick Hershey</a>
# Problems obtaining <a ajaxify="/ajax/friends/inactive/dialog?id=100002920489676" href="#" rel="dialog" role="button">Andrea Semadeni</a>
# Problems obtaining <a ajaxify="/ajax/friends/inactive/dialog?id=1428136425" href="#" rel="dialog" role="button">Cristóbal Criz Scotch</a>
# Problems obtaining <a ajaxify="/ajax/friends/inactive/dialog?id=1216261677" href="#" rel="dialog" role="button">Simone Wirz</a>
# Problems obtaining <a ajaxify="/ajax/friends/inactive/dialog?id=672020144" href="#" rel="dialog" role="button">Romain Bouillaguet</a>

# %%
def scrape_mutual_friends(s):
    login(s)
    edgelist = []
    friendslist = []
    
    #Get FriendsIDs
    with open('friends.csv', mode='r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        for i, row in enumerate(csv_reader):
            if i != 0:
                friendslist.append([row["Friend ID"],row["Friend Name"]])
                
    #Get my Id
    s.get("http://facebook.com/%s" % MY_SLUG)
    elem = s.find_element_by_xpath("//*")
    source_code = elem.get_attribute("outerHTML")
    soup = BeautifulSoup(source_code, 'lxml')
    my_id = re.search(r"profile_id=(\d*)", source_code).groups()[0]
    print("My ID: %s" % my_id)

    for friends in friendslist:
        print("Visiting friend: %s" % friends[1])
        s.get("https://www.facebook.com/browse/mutual_friends/?uid=%s&node=%s" % (my_id,friends[0]))
        elem = s.find_element_by_xpath("//*")
        source_code = elem.get_attribute("outerHTML")
        soup = BeautifulSoup(source_code, 'lxml')
        mutual_friends = soup.select(".fcb a")
        print("Found %s mutual friends" % len(mutual_friends))
        for friend in mutual_friends:
            edgelist.append([friends[0],json.loads(friend["data-gt"])["engagement"]["eng_tid"].encode("ascii","ignore")])

    with open('network.csv', mode='w') as myfile:
        mycsv = csv.writer(myfile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        mycsv.writerow(["From","To"])
        for edge in edgelist:
            mycsv.writerow([edge[0],edge[1]])

# %%
scrape_mutual_friends(s)
# Out:
# Logging into FB
# Probably already logged in...
# My ID: 1019764750
# Visiting friend: b'Nicole Zumstein'
# Found 39 mutual friends
# Visiting friend: b'Patrick Schoeck-Ritschard'
# Found 39 mutual friends
# Visiting friend: b'Silvan Wacker'
# Found 39 mutual friends
# Visiting friend: b'Valeria Wieser'
# Found 39 mutual friends
# Visiting friend: b'Sandra Rutschi'
# Found 39 mutual friends
# Visiting friend: b'Charlotte Walder'
# Found 39 mutual friends
# Visiting friend: b'Pirmin Meyer'
# Found 39 mutual friends
# Visiting friend: b'Hannes Weber'
# Found 39 mutual friends
# Visiting friend: b'Robin Gemmell'
# Found 39 mutual friends
# Visiting friend: b'Annina Bettschen-Huber'
# Found 39 mutual friends
# Visiting friend: b'Jakob Bchtold'
# Found 39 mutual friends
# Visiting friend: b'Mirjam Fuchs'
# Found 39 mutual friends
# Visiting friend: b'Dennis Bhler'
# Found 39 mutual friends
# Visiting friend: b'Christian Zuercher'
# Found 39 mutual friends
# Visiting friend: b'Till Bsi'
# Found 39 mutual friends
# Visiting friend: b'Carola Etter-Gick'
# Found 39 mutual friends
# Visiting friend: b'Pascal Unternaehrer'
# Visiting friend: b'Sebastian Hiller'
# Found 10 mutual friends
# Visiting friend: b'Christian Gurtner'
# Found 10 mutual friends
# Visiting friend: b'Clod Brnegger'
# Found 10 mutual friends
# Visiting friend: b'Chantal Hebeisen'
# Found 10 mutual friends
# Visiting friend: b'Sarah Bucher'
# Found 10 mutual friends
# Visiting friend: b'Simon Hungerbhler'
# Found 10 mutual friends
# Visiting friend: b'Christian Rmer'
# Found 10 mutual friends
# Visiting friend: b'Patrick Gut'
# Found 10 mutual friends
# Visiting friend: b'Karin Landolt'
# Found 10 mutual friends
# Visiting friend: b'Reto Flury'
# Found 10 mutual friends
# Visiting friend: b'Jamie Fox'
# Found 10 mutual friends
# Visiting friend: b'Sophie Resch'
# Found 10 mutual friends
# Visiting friend: b'Andri Bryner'
# Found 10 mutual friends
# Visiting friend: b'Michael Trost'
# Found 10 mutual friends
# Visiting friend: b'Walter von Arburg'
# Found 10 mutual friends
# Visiting friend: b'Lorenz Pfrunder'
# Found 10 mutual friends
# Visiting friend: b'Monika Schubarth'
# Found 10 mutual friends
# Visiting friend: b'Virginia Suter Reich'
# Found 10 mutual friends
# Visiting friend: b'Patrik Berger'
# Found 10 mutual friends
# Visiting friend: b'Linus Schpfer'
# Found 10 mutual friends
# Visiting friend: b'Jan Derrer'
# Found 10 mutual friends
# Visiting friend: b'Marcus May'
# Found 10 mutual friends
# Visiting friend: b'Rachel Van der Elst'
# Found 10 mutual friends
# Visiting friend: b'Li Lie'
# Found 10 mutual friends
# Visiting friend: b'Pedro San'
# Found 10 mutual friends
# Visiting friend: b'Jean-Martin Bttner'
# Found 10 mutual friends
# Visiting friend: b'Lukas Bnger'
# Found 10 mutual friends
# Visiting friend: b'Tho Tho'
# Found 10 mutual friends
# Visiting friend: b'Barbara Wegmann'
# Found 10 mutual friends
# Visiting friend: b'Christoph Eisenring'
# Found 10 mutual friends
# Visiting friend: b'Martin Freuler'
# Found 10 mutual friends
# Visiting friend: b'Sibylle Bhler'
# Found 10 mutual friends
# Visiting friend: b'Laura Bsiger'
# Found 10 mutual friends
# Visiting friend: b'Martin Mhlegg'
# Found 10 mutual friends
# Visiting friend: b'Salome Ritschard'
# Found 10 mutual friends
# Visiting friend: b'Martin Eggenberger'
# Found 10 mutual friends
# Visiting friend: b'Jasmin Lempert'
# Found 10 mutual friends
# Visiting friend: b'Julian Schmidli'
# Found 10 mutual friends
# Visiting friend: b'Chris B'
# Found 10 mutual friends
# Visiting friend: b'Gaby Oertli-Bosshard'
# Found 10 mutual friends
# Visiting friend: b'Eva Pfirter'
# Found 10 mutual friends
# Visiting friend: b'Dania Herrmann'
# Found 10 mutual friends
# Visiting friend: b'Mischa Weber'
# Found 10 mutual friends
# Visiting friend: b'David Sarasin'
# Found 10 mutual friends
# Visiting friend: b'Marcel Reuss'
# Found 10 mutual friends
# Visiting friend: b'Kana Nakajima'
# Found 10 mutual friends
# Visiting friend: b'Will Hershey'
# Found 10 mutual friends
# Visiting friend: b'Kai Mller'
# Found 10 mutual friends
# Visiting friend: b'Thomas Widmer'
# Found 10 mutual friends
# Visiting friend: b'Philippe Coradi'
# Found 10 mutual friends
# Visiting friend: b'Sibylle Ganz-Rber'
# Found 10 mutual friends
# Visiting friend: b'Heiner Fierz'
# Found 10 mutual friends
# Visiting friend: b'Ron Buchanan'
# Found 10 mutual friends
# Visiting friend: b'Alex Simian Tristan'
# Found 10 mutual friends
# Visiting friend: b'Christoph Kaminski'
# Found 10 mutual friends
# Visiting friend: b'Simon Libsig'
# Found 10 mutual friends
# Visiting friend: b'Ferry Hermida'
# Found 10 mutual friends
# Visiting friend: b'Michael Good'
# Found 10 mutual friends
# Visiting friend: b'Fabian Brndli'
# Found 10 mutual friends
# Visiting friend: b'Philipp Hofstetter'
# Found 10 mutual friends
# Visiting friend: b'Karin Helene Mller'
# Found 10 mutual friends
# Visiting friend: b'Blanca Serda Gil'
# Found 10 mutual friends
# Visiting friend: b'Lisa Luchsinger'
# Found 10 mutual friends
# Visiting friend: b'Flurina Lienhard'
# Found 10 mutual friends
# Visiting friend: b'Simone Rettich'
# Found 10 mutual friends
# Visiting friend: b'Jnos Rumpel'
# Found 10 mutual friends
# Visiting friend: b'Daniela Specht'
# Found 10 mutual friends
# Visiting friend: b'Emanuel Tonet'
# Found 10 mutual friends
# Visiting friend: b'Sandra Flckiger'
# Found 10 mutual friends
# Visiting friend: b'Pedro Tortellini'
# Found 10 mutual friends
# Visiting friend: b'Rafaela Luar'
# Found 10 mutual friends
# Visiting friend: b'Tristan Winkler'
# Found 10 mutual friends
# Visiting friend: b'Daniel Fritzsche'
# Found 10 mutual friends
# Visiting friend: b'Kaspar B Uenger'
# Found 10 mutual friends
# Visiting friend: b'Aqua Yost'
# Found 10 mutual friends
# Visiting friend: b'Bruno Amstutz'
# Found 10 mutual friends
# Visiting friend: b'Tamara Loga'
# Found 10 mutual friends
# Visiting friend: b'Jogger Jochen'
# Found 10 mutual friends
# Visiting friend: b'Andrea Schmider'
# Found 10 mutual friends
# Visiting friend: b'Sabrina Meister'
# Found 10 mutual friends
# Visiting friend: b'Patrick Mink'
# Found 10 mutual friends
# Visiting friend: b'Lukas Reichel'
# Found 10 mutual friends
# Visiting friend: b'Mario Staeuble'
# Found 10 mutual friends
# Visiting friend: b'Cori Mar'
# Found 10 mutual friends
# Visiting friend: b'Marius Beerli'
# Found 10 mutual friends

# %%
import networkx as nx

def create_user_network():
    friendslist = []
    edgelist = []
    
    with open('friends.csv', mode='r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        for i, row in enumerate(csv_reader):
            if i != 0:
                friendslist.append([row["Friend ID"],row["Friend Name"]])        

    with open('network.csv', mode='r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        for i, row in enumerate(csv_reader):
            if i != 0:
                edgelist.append([row["From"],row["To"]])
    
    G  = nx.Graph(name="Friends")
                            
    for friend in friendslist:
        G.add_node(friend[0],label=friend[1], size=1)

    for edge in edgelist:
        G.add_edge(edge[0],edge[1],weight=1)
   
    nx.write_gexf(G,"Marius_Friends.gexf")

# %%
create_user_network()
