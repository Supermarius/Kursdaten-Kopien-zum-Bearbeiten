# %%
from bs4 import BeautifulSoup
import pandas as pd
import time
import os   # Das ist ein Syteminterface-Tool (um etwas im System zu machen. hier: eine Liste des Ordners anzeigen)
import re
from tqdm import tqdm

# %%
lst = os.listdir('pages/')
# wenn mans sortiert möchte, kann man noch sorted einfügen: 
lst = sorted(os.listdir('pages/'))

# %%
lst
# Out:
# ['page.htm',
#  'page0.htm',
#  'page1.htm',
#  'page10.htm',
#  'page11.htm',
#  'page12.htm',
#  'page13.htm',
#  'page14.htm',
#  'page15.htm',
#  'page16.htm',
#  'page17.htm',
#  'page18.htm',
#  'page19.htm',
#  'page2.htm',
#  'page20.htm',
#  'page21.htm',
#  'page22.htm',
#  'page23.htm',
#  'page24.htm',
#  'page25.htm',
#  'page26.htm',
#  'page27.htm',
#  'page28.htm',
#  'page29.htm',
#  'page3.htm',
#  'page30.htm',
#  'page31.htm',
#  'page32.htm',
#  'page33.htm',
#  'page34.htm',
#  'page4.htm',
#  'page5.htm',
#  'page6.htm',
#  'page7.htm',
#  'page8.htm',
#  'page9.htm']

# %%
file = open('pages/' + lst[0], 'r')
text = file.read()
h = BeautifulSoup(text, 'html.parser')

# %%
# Ein einzelnes Element aus dieser Liste anschauen:
daten = h.find_all('tr', {'class':'ng-scope'})
daten[0]
# Hier sehen wir: der Name verbirgt sich in einem div-Tag
# Out:
# <tr class="ng-scope" ng-repeat="row in $data"><!-- ngRepeat: col in $columns --><!-- ngIf: col.show() --><td class="ng-scope" data-title-text="business name" filter="$listCtrl.filters[col.name]" ng-if="col.show()" ng-repeat="col in $columns"><!-- ngIf: col.name === 'company' --><div class="company-name ng-scope" ng-attr-title="{{row.name}}" ng-if="col.name === 'company'" title='Bäckerei "gsund" AG'><a class="ng-binding" href="/en/search/entity/list/firm/1167884?name=b%C3%A4ckerei&amp;searchType=exact" ng-bind-html="highlight(row.name, $listCtrl.tableParams.filter(), 'name')" ng-class="{ 'strike-thru': row.status === 'GELOESCHT'}" ui-sref=".details({ ehraid: row.ehraid })">Bäckerei "gsund" AG</a></div><!-- end ngIf: col.name === 'company' --><!-- ngIf: col.name === 'legalSeat' --><!-- ngIf: col.getValue --></td><!-- end ngIf: col.show() --><!-- end ngRepeat: col in $columns --><!-- ngIf: col.show() --><td class="ng-scope" data-title-text="excerpt" filter="$listCtrl.filters[col.name]" ng-if="col.show()" ng-repeat="col in $columns"><!-- ngIf: col.name === 'company' --><!-- ngIf: col.name === 'legalSeat' --><!-- ngIf: col.getValue --><div class="ng-binding ng-scope" ng-bind-html="col.getValue(this, row)" ng-if="col.getValue"><a href="https://sz.chregister.ch/cr-portal/auszug/zefix.xhtml?uid=CHE-240.641.011&amp;lang=de" style="margin: 0em 1em;" target="_blank" title="excerpt (Web)"><span class="icon icon--external"></span></a> </div><!-- end ngIf: col.getValue --></td><!-- end ngIf: col.show() --><!-- end ngRepeat: col in $columns --><!-- ngIf: col.show() --><td class="ng-scope" data-title-text="UID / UID register" filter="$listCtrl.filters[col.name]" ng-if="col.show()" ng-repeat="col in $columns"><!-- ngIf: col.name === 'company' --><!-- ngIf: col.name === 'legalSeat' --><!-- ngIf: col.getValue --><div class="ng-binding ng-scope" ng-bind-html="col.getValue(this, row)" ng-if="col.getValue"><span class="no-wrap">CHE-240.641.011<a class="uid-link" href="https://www.uid.admin.ch/Detail.aspx?uid_id=CHE240641011" target="_blank"><span class="icon icon--external icon--after"></span></a></span></div><!-- end ngIf: col.getValue --></td><!-- end ngIf: col.show() --><!-- end ngRepeat: col in $columns --><!-- ngIf: col.show() --><!-- end ngRepeat: col in $columns --><!-- ngIf: col.show() --><td class="ng-scope" data-title-text="legal form" filter="$listCtrl.filters[col.name]" ng-if="col.show()" ng-repeat="col in $columns"><!-- ngIf: col.name === 'company' --><!-- ngIf: col.name === 'legalSeat' --><!-- ngIf: col.getValue --><div class="ng-binding ng-scope" ng-bind-html="col.getValue(this, row)" ng-if="col.getValue"><span title="Corporation">Ltd</span></div><!-- end ngIf: col.getValue --></td><!-- end ngIf: col.show() --><!-- end ngRepeat: col in $columns --><!-- ngIf: col.show() --><td class="ng-scope" data-title-text="seat" filter="$listCtrl.filters[col.name]" ng-if="col.show()" ng-repeat="col in $columns"><!-- ngIf: col.name === 'company' --><!-- ngIf: col.name === 'legalSeat' --><div class="company-seat ng-scope" ng-if="col.name === 'legalSeat'"><span class="ng-binding" ng-bind-html="highlight(row.legalSeat, $listCtrl.tableParams.filter(), 'legalSeat')">Feusisberg</span></div><!-- end ngIf: col.name === 'legalSeat' --><!-- ngIf: col.getValue --></td><!-- end ngIf: col.show() --><!-- end ngRepeat: col in $columns --><!-- ngIf: col.show() --><td class="ng-scope" data-title-text="canton / rc" filter="$listCtrl.filters[col.name]" ng-if="col.show()" ng-repeat="col in $columns"><!-- ngIf: col.name === 'company' --><!-- ngIf: col.name === 'legalSeat' --><!-- ngIf: col.getValue --><div class="ng-binding ng-scope" ng-bind-html="col.getValue(this, row)" ng-if="col.getValue"><a href="https://www.sz.ch/kanton/wirtschaft/handelsregister/handelsregister-schwyz.html/72-210-94-1916-1890" target="_blank" title="Handelsregisteramt des Kantons Schwyz">SZ - Schwyz</a></div><!-- end ngIf: col.getValue --></td><!-- end ngIf: col.show() --><!-- end ngRepeat: col  ...

# %%
daten[0].find_all("div")
# Out:
# [<div class="company-name ng-scope" ng-attr-title="{{row.name}}" ng-if="col.name === 'company'" title='Bäckerei "gsund" AG'><a class="ng-binding" href="/en/search/entity/list/firm/1167884?name=b%C3%A4ckerei&amp;searchType=exact" ng-bind-html="highlight(row.name, $listCtrl.tableParams.filter(), 'name')" ng-class="{ 'strike-thru': row.status === 'GELOESCHT'}" ui-sref=".details({ ehraid: row.ehraid })">Bäckerei "gsund" AG</a></div>,
#  <div class="ng-binding ng-scope" ng-bind-html="col.getValue(this, row)" ng-if="col.getValue"><a href="https://sz.chregister.ch/cr-portal/auszug/zefix.xhtml?uid=CHE-240.641.011&amp;lang=de" style="margin: 0em 1em;" target="_blank" title="excerpt (Web)"><span class="icon icon--external"></span></a> </div>,
#  <div class="ng-binding ng-scope" ng-bind-html="col.getValue(this, row)" ng-if="col.getValue"><span class="no-wrap">CHE-240.641.011<a class="uid-link" href="https://www.uid.admin.ch/Detail.aspx?uid_id=CHE240641011" target="_blank"><span class="icon icon--external icon--after"></span></a></span></div>,
#  <div class="ng-binding ng-scope" ng-bind-html="col.getValue(this, row)" ng-if="col.getValue"><span title="Corporation">Ltd</span></div>,
#  <div class="company-seat ng-scope" ng-if="col.name === 'legalSeat'"><span class="ng-binding" ng-bind-html="highlight(row.legalSeat, $listCtrl.tableParams.filter(), 'legalSeat')">Feusisberg</span></div>,
#  <div class="ng-binding ng-scope" ng-bind-html="col.getValue(this, row)" ng-if="col.getValue"><a href="https://www.sz.ch/kanton/wirtschaft/handelsregister/handelsregister-schwyz.html/72-210-94-1916-1890" target="_blank" title="Handelsregisteramt des Kantons Schwyz">SZ - Schwyz</a></div>]

# %%
name = daten[0].find_all("div")[0].text
ort = daten[0].find_all("div")[4].text
ID = daten[0].find_all("div")[2].text
URL = daten[0].find_all("a")[1]["href"]

datensatz = {"Name" : name, "Ort" : ort, "ID-Nr." : ID, "Website" : URL}

print(datensatz)
# Out:
# {'Name': 'Bäckerei "gsund" AG', 'Ort': 'Feusisberg', 'ID-Nr.': 'CHE-240.641.011', 'Website': 'https://sz.chregister.ch/cr-portal/auszug/zefix.xhtml?uid=CHE-240.641.011&lang=de'}

# %%
df = pd.DataFrame([datensatz])
df
# Out:
#                   Name         Ort           ID-Nr.  \
# 0  Bäckerei "gsund" AG  Feusisberg  CHE-240.641.011
#
#                                              Website
# 0  https://sz.chregister.ch/cr-portal/auszug/zefi...

# %% [markdown]
# **Jetzt loopen wir das Ganze:**

# %%
datenliste = []

daten = h.find_all('tr', {'class':'ng-scope'})

for zeile in daten:
    
    name = zeile.find_all("div")[0].text
    ort = zeile.find_all("div")[4].text
    ID = zeile.find_all("div")[2].text
    URL = zeile.find_all("a")[1]["href"]

    datensatz = {"Name" : name, 
                 "Ort" : ort, 
                 "ID-Nr." : ID, 
                 "Website" : URL}
    
    datenliste.append(datensatz)
    
df = pd.DataFrame(datenliste)
df
# Out:
#                                                 Name                  Ort  \
# 0                                Bäckerei "gsund" AG           Feusisberg
# 1                  Bäckerei & Catering M Janicijevic               Zürich
# 2                 Bäckerei & Konditorei, Biner & Co.              Zermatt
# 3            Bäckerei + Party-Service Sandra Bircher          Wölflinswil
# 4                   Bäckerei - Konditorei - Café Gut             Willisau
# 5   Bäckerei - Konditorei - Lebensmittel Leuenberger      Erlinsbach (SO)
# 6        Bäckerei - Konditorei - Lebensmittel Oester            Adelboden
# 7  Bäckerei - Konditorei Adula, Georg Schmid und ...             Tujetsch
# 8                   Bäckerei - Konditorei D. Pfister            Uetendorf
# 9              Bäckerei - Konditorei Eichenberger AG  Langnau im Emmental
#
#             ID-Nr.                                            Website
# 0  CHE-240.641.011  https://sz.chregister.ch/cr-portal/auszug/zefi...
# 1  CHE-114.960.579  https://zh.chregister.ch/cr-portal/auszug/zefi...
# 2  CHE-102.073.772  https://vo.chregister.ch/cr-portal/auszug/zefi...
# 3  CHE-115.910.495  https://ag.chregister.ch/cr-portal/auszug/zefi...
# 4  CHE-112.034.070  https://lu.chregister.ch/cr-portal/auszug/zefi...
# 5  CHE-107.195.164  https://so.chregister.ch/cr-portal/auszug/zefi...
# 6  CHE-109.306.718  https://be.chregister.ch/cr-portal/auszug/zefi...
# 7  CHE-438.593.065  https://gr.chregister.ch/cr-portal/auszug/zefi...
# 8  CHE-116.198.463  https://be.chregister.ch/cr-portal/auszug/zefi...
# 9  CHE-313.666.724  https://be.chregister.ch/cr-portal/auszug/zefi...

# %% [markdown]
# Bei **Loops in Loops** packt man den Loop am besten in eine **neu definierte Funktion**, damits übersichtlicher bleibt:

# %%
def extractbakeries(elem):
    
    datenliste = []

    daten = elem.find_all('tr', {'class':'ng-scope'})

    for zeile in daten:
    
        name = zeile.find_all("div")[0].text
        ort = zeile.find_all("div")[4].text
        ID = zeile.find_all("div")[2].text
        URL = zeile.find_all("a")[1]["href"]

        datensatz = {"Name" : name, 
                     "Ort" : ort, 
                     "ID-Nr." : ID, 
                     "Website" : URL}
    
        datenliste.append(datensatz)
    
    df = pd.DataFrame(datenliste)
    return(df)

# %% [markdown]
# Jetzt können wir mit dieser Funktion ganez elegant für jede Seite (h) das Resultat anzeigen lassen (indem wir den Seitenwert anpassen:

# %%
extractbakeries(h)
# Out:
#                                                 Name                  Ort  \
# 0                                Bäckerei "gsund" AG           Feusisberg
# 1                  Bäckerei & Catering M Janicijevic               Zürich
# 2                 Bäckerei & Konditorei, Biner & Co.              Zermatt
# 3            Bäckerei + Party-Service Sandra Bircher          Wölflinswil
# 4                   Bäckerei - Konditorei - Café Gut             Willisau
# 5   Bäckerei - Konditorei - Lebensmittel Leuenberger      Erlinsbach (SO)
# 6        Bäckerei - Konditorei - Lebensmittel Oester            Adelboden
# 7  Bäckerei - Konditorei Adula, Georg Schmid und ...             Tujetsch
# 8                   Bäckerei - Konditorei D. Pfister            Uetendorf
# 9              Bäckerei - Konditorei Eichenberger AG  Langnau im Emmental
#
#             ID-Nr.                                            Website
# 0  CHE-240.641.011  https://sz.chregister.ch/cr-portal/auszug/zefi...
# 1  CHE-114.960.579  https://zh.chregister.ch/cr-portal/auszug/zefi...
# 2  CHE-102.073.772  https://vo.chregister.ch/cr-portal/auszug/zefi...
# 3  CHE-115.910.495  https://ag.chregister.ch/cr-portal/auszug/zefi...
# 4  CHE-112.034.070  https://lu.chregister.ch/cr-portal/auszug/zefi...
# 5  CHE-107.195.164  https://so.chregister.ch/cr-portal/auszug/zefi...
# 6  CHE-109.306.718  https://be.chregister.ch/cr-portal/auszug/zefi...
# 7  CHE-438.593.065  https://gr.chregister.ch/cr-portal/auszug/zefi...
# 8  CHE-116.198.463  https://be.chregister.ch/cr-portal/auszug/zefi...
# 9  CHE-313.666.724  https://be.chregister.ch/cr-portal/auszug/zefi...

# %% [markdown]
# also so:

# %%
file = open('pages/' + lst[1], 'r')   # hier habe ich die Seite verändert
text = file.read()
h = BeautifulSoup(text, 'html.parser')

extractbakeries(h)
# Out:
#                                                 Name          Ort  \
# 0                      BÄCKEREI - KONDITOREI FÄSSLER         Rüte
# 1  Bäckerei - Konditorei Furter, Nachfolger Mario...        Aarau
# 2                       Bäckerei - Konditorei Gübeli  St. Stephan
# 3                      Bäckerei - Konditorei Hermann        Muhen
# 4          Bäckerei - Konditorei Jean-Pierre Grindat       Orpund
# 5                  Bäckerei - Konditorei Leuenberger   Zollikofen
# 6                   Bäckerei - Konditorei Maier GmbH    Böttstein
# 7                  Bäckerei - Konditorei Märchy GmbH  Glarus Nord
# 8                  Bäckerei - Konditorei Not Clalüna        Scuol
# 9             Bäckerei - Konditorei Unternährer & Co  Kappel (SO)
#
#             ID-Nr.                                            Website
# 0  CHE-115.132.898  https://ai.chregister.ch/cr-portal/auszug/zefi...
# 1  CHE-109.386.806  https://ag.chregister.ch/cr-portal/auszug/zefi...
# 2  CHE-114.920.189  https://be.chregister.ch/cr-portal/auszug/zefi...
# 3  CHE-107.066.035  https://ag.chregister.ch/cr-portal/auszug/zefi...
# 4  CHE-106.154.151  https://be.chregister.ch/cr-portal/auszug/zefi...
# 5  CHE-107.148.259  https://be.chregister.ch/cr-portal/auszug/zefi...
# 6  CHE-200.539.725  https://ag.chregister.ch/cr-portal/auszug/zefi...
# 7  CHE-105.728.428  https://gl.chregister.ch/cr-portal/auszug/zefi...
# 8  CHE-107.695.188  https://gr.chregister.ch/cr-portal/auszug/zefi...
# 9  CHE-112.494.017  https://so.chregister.ch/cr-portal/auszug/zefi...
