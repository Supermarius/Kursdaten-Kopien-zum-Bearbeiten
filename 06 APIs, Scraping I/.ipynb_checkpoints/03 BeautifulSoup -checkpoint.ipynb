# %% [markdown]
# # Einführung in BeautifulSoup, einlesen von Files

# %% [markdown]
# Und als aller Erstes wollen wir die Developer Tools kennenlernen:
#
# - Gehen wir auf: www.srf.ch.
# - Öffnen den Chrome Browser. Die Developer Tools findest DU im Menü unter More Tools -> Developer Tools. Shortcuts: F12, Str-Ctr-I oder Cmd + Opt + I (alle Browser die Dev Tools, wir fokussieren hier auf den Chrome Browser)
# - Der Reiter, der uns interessiert, ist: “Elements”. Steuere ihn an.
# - Wir können hier zwischen Mobilansicht und Desktop wechseln
# - Oder Elemente auf der Website suchen. Wähle den Pfeil an. Und suche nun etwas auf der Website.
# - Hier können wir auch Texte manipulieren, teste es auf www.srf.ch.
# - Aber das interessiert uns nicht. Wir wollen die Struktur der Website kennenlernen. Vertiefen wir uns eine Weile in diese Struktur. Je besser wir sie kennen, desto einfacher ist es, Daten auszulesen.
# - Das sollte euch nun etwas bekannter vorkommen. Ihr habt eben selber solche Zeilen geschrieben.

# %% [markdown]
# Gehen wir zurück zu dem File, den ihr eben selber bearbeitet habt. Zuerst müssen wir das File einlesen.

# %%
file = open('02 HTML Code.htm', 'r')

# %% [markdown]
# ```open``` ist eine eingebaute Funktion von Python. Ihr findet hier [eine Zusammenstellung](https://docs.python.org/2/library/functions.html) all dieser Funktionen. Es gibt neben ```r```und ```w``` noch die Binary modi. ```rb```und ```wb```. Binary heisst, dass der Computer sich die Buchstaben im Format abspeichert, der ihm am besten liegt. 0 und 1. E = 01000101, F = 01000110, ihr findet mehr [hier](http://sticksandstones.kstrom.com/appen.html) (allerdings Python 2) und mehr [hier](https://docs.python.org/3/tutorial/inputoutput.html).

# %%
file2 = open('testingopen.txt', 'w')

# %% [markdown]
# Oben seht ihr das Ergebnis, wenn ihr ein File schreibt. Im selben Ordner wie dieses Jupyter Notebook erscheint nun eben dieses file2. Das einfach der vollständigkeitshalber.

# %%
file.read()
# Out:
# '<h1> Mein Lebenslauf</h1>\n\n<!doctype html>\n<html lang="de">\n\n<head>\n    <title>Die frühen Jahre</title>\n</head>\n\n<body style="color:black;">\n    <h2>Eine erschöpfende Liste der Heldentaten seiner Majestät</h2>\n    <p>Sowas könnte jeder – aber ich habs auch tatsächlich gemacht. </p>\n    <ul>\n    <li><b>Mit 2 Monaten:</b> Schlange in Krippe erwürgt</li><br>\n    <img src="snake.jpg" alt="Das Opfer" style="width:500px;">\n    <p>Der WWF sagt dazu: <q>Build a future where people live in harmony with nature.</q></p>\n    <li><b>Mit 1 Jahr:</b> erster Marathonlauf</li>\n    <li><b>Mit 2 Jahren:</b> Der Welt den Krieg erklärt. Und gewonnen.</li>\n    <li><b>Mit 4 Jahren:</b> Die Naturgesetze verbessert.</li><br>\n    <iframe src="https://giphy.com/embed/CfirwIjZdHkWc" width="474" height="480" frameBorder="0" class="giphy-embed" allowFullScreen></iframe>\n</body style="color:blue;">\n</ul>\n<body>\n<h2>Meine Orden</h2>\n<p style="color:red;">Hier steht der Einleitungstext meiner Website. </p>\n\n<table style="width:100%">\n  <tr>\n    <th>Anlass</th>\n    <th>Orden</th>\n    <th>Kategorie</th>\n  </tr>\n  <tr>\n    <td>Olypiade</td>\n    <td>Smith</td>\n    <td>50</td>\n  </tr>\n  <tr>\n    <td>Eve</td>\n    <td>Jackson</td>\n    <td>94</td>\n  </tr>\n</table>\n\n\n<h2>Das ist die dritte Überschrift</h2>\n<p>Hier steht der Einleitungstext meiner Website. </p>\n<ul>\n<li>Erster Listenpunkt</li>\n<li>Zweiter Listenpunkt</li>\n<li>Dritter Listenpunkt</li>\n<li>Vierter Listenpunkt</li>\n</body>\n'

# %%
text = file.read()

# %%
file = open('02 HTML Code.htm', 'r')

# %%
# So liest er alles bis zum Zeilenumbruch (newline)

file.readline()
# Out:
# '<h1> Mein Lebenslauf</h1>\n'

# %%
#Das sieht aber nicht sehr schön aus
file = open('02 HTML Code.htm', 'r')
text = file.read()
text
# Out:
# '<h1> Mein Lebenslauf</h1>\n\n<!doctype html>\n<html lang="de">\n\n<head>\n    <title>Die frühen Jahre</title>\n</head>\n\n<body style="color:black;">\n    <h2>Eine erschöpfende Liste der Heldentaten seiner Majestät</h2>\n    <p>Sowas könnte jeder – aber ich habs auch tatsächlich gemacht. </p>\n    <ul>\n    <li><b>Mit 2 Monaten:</b> Schlange in Krippe erwürgt</li><br>\n    <img src="snake.jpg" alt="Das Opfer" style="width:500px;">\n    <p>Der WWF sagt dazu: <q>Build a future where people live in harmony with nature.</q></p>\n    <li><b>Mit 1 Jahr:</b> erster Marathonlauf</li>\n    <li><b>Mit 2 Jahren:</b> Der Welt den Krieg erklärt. Und gewonnen.</li>\n    <li><b>Mit 4 Jahren:</b> Die Naturgesetze verbessert.</li><br>\n    <iframe src="https://giphy.com/embed/CfirwIjZdHkWc" width="474" height="480" frameBorder="0" class="giphy-embed" allowFullScreen></iframe>\n</body style="color:blue;">\n</ul>\n<body>\n<h2>Meine Orden</h2>\n<p style="color:red;">Hier steht der Einleitungstext meiner Website. </p>\n\n<table style="width:100%">\n  <tr>\n    <th>Anlass</th>\n    <th>Orden</th>\n    <th>Kategorie</th>\n  </tr>\n  <tr>\n    <td>Olypiade</td>\n    <td>Smith</td>\n    <td>50</td>\n  </tr>\n  <tr>\n    <td>Eve</td>\n    <td>Jackson</td>\n    <td>94</td>\n  </tr>\n</table>\n\n\n<h2>Das ist die dritte Überschrift</h2>\n<p>Hier steht der Einleitungstext meiner Website. </p>\n<ul>\n<li>Erster Listenpunkt</li>\n<li>Zweiter Listenpunkt</li>\n<li>Dritter Listenpunkt</li>\n<li>Vierter Listenpunkt</li>\n</body>\n'

# %% [markdown]
# Mit BeautifulSoup kann man HTML-Sites in eine Form bringen, die es uns Menschen wieder einfacher macht, die Inhalte zu lesen. Wir beginnne wir immer, indem wir die Library installieren. Wie mit ```!pip import BS4```falls ihr das nicht schon getan habt. Und dann importieren wir die Library.

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(text, "lxml")

# %%
soup.find('h2')
# Out:
# <h2>Eine erschöpfende Liste der Heldentaten seiner Majestät</h2>

# %%
soup.find_all('h2')
# Out:
# [<h2>Eine erschöpfende Liste der Heldentaten seiner Majestät</h2>,
#  <h2>Meine Orden</h2>,
#  <h2>Das ist die dritte Überschrift</h2>]

# %%
#Bauen wir eine neue Liste; die .text-Funktion reduziert den Output auf den reinen Text.
new_lst = []
for elem in soup.find_all('h2'):
    new_lst.append(elem.text)

# %%
new_lst
# Out:
# ['Eine erschöpfende Liste der Heldentaten seiner Majestät',
#  'Meine Orden',
#  'Das ist die dritte Überschrift']

# %%
#Bauen wir eine Liste von Dictionaries
new_lst = []
for elem in soup.find_all('h2'):
    mini_dict = {'Überschrift':elem.text}
    new_lst.append(mini_dict)

# %%
import pandas as pd

# %%
pd.DataFrame(new_lst)
# Out:
#                                          Überschrift
# 0  Eine erschöpfende Liste der Heldentaten seiner...
# 1                                        Meine Orden
# 2                     Das ist die dritte Überschrift

# %% [markdown]
# ## Gehen wir auf eine Seite mit mehr Inhalt, aber immer noch sehr strukturiert: Ein RSS-Feed
# Was wir hier haben, ist die aktuelle Ausbuchung der Parkplätze in der Stadt Zürich. Sie werden von der Stadt in einem RSS Feed abgeboten. Schauen wir uns den [Link einmal an](http://www.plszh.ch/plsFeed/rss). Nicht sehr lesbar, aber äusserst strukturiert. Lesen wir die Plätze aus.

# %%
import requests

# %%
r = requests.get('http://www.plszh.ch/plsFeed/rss') #Besuchen wir die URL

# %%
contents = r.text #Wandeln wir den Text in ein Format um, mit dem BeautifulSoup umgehen kann.
soup = BeautifulSoup(contents,"xml") #Geben wir das an BeautifulSoup weiter
titles = soup.find_all('title') #Nun lesen wir Titel aus.
len(titles) #Schauen wir, wie lange die Titel sind.
# Out:
# 38

# %%
titles[0]
# Out:
# <title>FEED Parkleitsystem Stadt Zürich</title>

# %%
titles[1]
# Out:
# <title>Parkgarage am Central / Seilergraben</title>

# %%
titles[1].text
# Out:
# 'Parkgarage am Central / Seilergraben'

# %%
descr = soup.find_all('description')
descr[1]
# Out:
# <description>open /    0</description>

# %%
#Bauen wir die eigene Liste. (Mit dem Zip-Befehl werden zwei gleich lange Listen zusammengezippt.)
lst = []
for garage,parkplatzzahl in zip(titles,descr):
    
    mini_dict = {'Parkgarage':garage.text,
                 'Descr':parkplatzzahl.text}
    
    lst.append(mini_dict)

# %%
lst
# Out:
# [{'Parkgarage': 'FEED Parkleitsystem Stadt Zürich',
#   'Descr': 'http://www.plszh.ch/plsFeed/rss?type=rss_0.92 | rss_0.93 | rss_0.94 | rss_1.0 | rss_2.0 (=default) | atom_0.3 | atom_1.0'},
#  {'Parkgarage': 'Parkgarage am Central / Seilergraben',
#   'Descr': 'open /    0'},
#  {'Parkgarage': 'Parkhaus Accu / Otto-Schütz-Weg', 'Descr': 'open /  128'},
#  {'Parkgarage': 'Parkhaus Albisriederplatz / Badenerstrasse 380',
#   'Descr': 'open /   56'},
#  {'Parkgarage': 'Parkhaus Bleicherweg / Beethovenstrasse 35',
#   'Descr': 'open /    3'},
#  {'Parkgarage': 'Parkhaus Center Eleven / Sophie-Täuber-Strasse 4',
#   'Descr': 'open /  155'},
#  {'Parkgarage': 'Parkhaus City Parking / Gessnerallee 14',
#   'Descr': 'open /   92'},
#  {'Parkgarage': 'Parkhaus Cityport / Affolternstrasse 56',
#   'Descr': 'open /   19'},
#  {'Parkgarage': 'Parkhaus Crowne Plaza / Badenerstrasse 420',
#   'Descr': 'open /  173'},
#  {'Parkgarage': 'Parkhaus Dorflinde / Schwamendingenstrasse 31',
#   'Descr': 'open /   29'},
#  {'Parkgarage': 'Parkhaus Feldegg / Riesbachstrasse 7',
#   'Descr': 'open /   25'},
#  {'Parkgarage': 'Parkhaus Globus / Löwenstrasse 50', 'Descr': 'open /   11'},
#  {'Parkgarage': 'Parkhaus Hardau II / Bullingerstrasse 73',
#   'Descr': 'open /   97'},
#  {'Parkgarage': 'Parkhaus Hauptbahnhof / Sihlquai 41', 'Descr': 'open /   57'},
#  {'Parkgarage': 'Parkhaus Hohe Promenade / Rämistrasse 22a',
#   'Descr': 'open /  276'},
#  {'Parkgarage': 'Parkhaus Jelmoli / Steinmühleplatz 1',
#   'Descr': 'open /    0'},
#  {'Parkgarage': 'Parkhaus Jungholz / Jungholzstrasse 19',
#   'Descr': 'open /   92'},
#  {'Parkgarage': 'Parkhaus Max-Bill-Platz / Armin-Bollinger-Weg',
#   'Descr': 'open /   79'},
#  {'Parkgarage': 'Parkhaus Messe Zürich AG / Andreasstrasse 65',
#   'Descr': 'open /  999'},
#  {'Parkgarage': 'Parkhaus Nordhaus / Siewerdtstrasse 8',
#   'Descr': 'open /   36'},
#  {'Parkgarage': 'Parkhaus Octavo / Brown-Boveri-Strasse 2',
#   'Descr': 'open /  109'},
#  {'Parkgarage': 'Parkhaus Opéra / Schillerstrasse 5', 'Descr': 'open /   79'},
#  {'Parkgarage': 'Parkhaus P West / Förrlibuckstrasse 151',
#   'Descr': 'open /  255'},
#  {'Parkgarage': 'Parkhaus Park Hyatt / Beethovenstrasse 21',
#   'Descr': 'open /   92'},
#  {'Parkgarage': 'Parkhaus Parkside / Sophie-Täuber-Strasse 10',
#   'Descr': 'open /    1'},
#  {'Parkgarage': 'Parkhaus Pfingstweid / Pfingstweidstrasse 1',
#   'Descr': 'open /   57'},
#  {'Parkgarage': 'Parkhaus Stampfenbach / Niklausstrasse 1',
#   'Descr': 'open /   84'},
#  {'Parkgarage': 'Parkhaus Talgarten / Nüschelerstrasse 31',
#   'Descr': 'open /    5'},
#  {'Parkgarage': 'Parkhaus USZ Nord / Frauenklinikstrasse',
#   'Descr': 'open /    1'},
#  {'Parkgarage': 'Parkhaus Uni Irchel / Winterthurerstrasse 181',
#   'Descr': 'open /  411'},
#  {'Parkgarage': 'Parkhaus Urania / Uraniastrasse 3', 'Descr': 'open /  101'},
#  {'Parkgarage': 'Parkhaus Utoquai / Färberstrasse 6', 'Descr': 'open /   20'},
#  {'Parkgarage': 'Parkhaus Züri 11 Shopping / Nansenstrasse 5/7',
#   'Descr': 'open /   12'},
#  {'Parkgarage': 'Parkhaus Zürichhorn / Dufourstrasse 142',
#   'Descr': 'open /   37'},
#  {'Parkgarage': 'Parkplatz Eisfeld / Thurgauerstrasse 54',
#   'Descr': 'open /   32'},
#  {'Parkgarage': 'Parkplatz Theater 11 / Dörfli-/Thurgauerstrasse',
#   'Descr': 'open /  134'},
#  {'Parkgarage': 'Parkplatz USZ Süd / Gloriastrasse', 'Descr': 'open /    0'},
#  {'Parkgarage': 'Puls 5 Parkgarage / Giessereistrasse 18',
#   'Descr': 'open /   14'}]

# %%
pd.DataFrame(lst).head()
# Mit Head zeigts in der Liste nur die ersten Elemente an...
# Out:
#                                                Descr  \
# 0  http://www.plszh.ch/plsFeed/rss?type=rss_0.92 ...
# 1                                        open /    0
# 2                                        open /  128
# 3                                        open /   56
# 4                                        open /    3
#
#                                        Parkgarage
# 0                FEED Parkleitsystem Stadt Zürich
# 1            Parkgarage am Central / Seilergraben
# 2                 Parkhaus Accu / Otto-Schütz-Weg
# 3  Parkhaus Albisriederplatz / Badenerstrasse 380
# 4      Parkhaus Bleicherweg / Beethovenstrasse 35

# %%
pd.DataFrame(lst)[1:]
# das [:1] bedeutet: alles ab Zeile 1 aufwärts)
# Out:
#           Descr                                        Parkgarage
# 1   open /    0              Parkgarage am Central / Seilergraben
# 2   open /  128                   Parkhaus Accu / Otto-Schütz-Weg
# 3   open /   56    Parkhaus Albisriederplatz / Badenerstrasse 380
# 4   open /    3        Parkhaus Bleicherweg / Beethovenstrasse 35
# 5   open /  155  Parkhaus Center Eleven / Sophie-Täuber-Strasse 4
# 6   open /   92           Parkhaus City Parking / Gessnerallee 14
# 7   open /   19           Parkhaus Cityport / Affolternstrasse 56
# 8   open /  173        Parkhaus Crowne Plaza / Badenerstrasse 420
# 9   open /   29     Parkhaus Dorflinde / Schwamendingenstrasse 31
# 10  open /   25              Parkhaus Feldegg / Riesbachstrasse 7
# 11  open /   11                 Parkhaus Globus / Löwenstrasse 50
# 12  open /   97          Parkhaus Hardau II / Bullingerstrasse 73
# 13  open /   57               Parkhaus Hauptbahnhof / Sihlquai 41
# 14  open /  276         Parkhaus Hohe Promenade / Rämistrasse 22a
# 15  open /    0              Parkhaus Jelmoli / Steinmühleplatz 1
# 16  open /   92            Parkhaus Jungholz / Jungholzstrasse 19
# 17  open /   79     Parkhaus Max-Bill-Platz / Armin-Bollinger-Weg
# 18  open /  999      Parkhaus Messe Zürich AG / Andreasstrasse 65
# 19  open /   36             Parkhaus Nordhaus / Siewerdtstrasse 8
# 20  open /  109          Parkhaus Octavo / Brown-Boveri-Strasse 2
# 21  open /   79                Parkhaus Opéra / Schillerstrasse 5
# 22  open /  255           Parkhaus P West / Förrlibuckstrasse 151
# 23  open /   92         Parkhaus Park Hyatt / Beethovenstrasse 21
# 24  open /    1      Parkhaus Parkside / Sophie-Täuber-Strasse 10
# 25  open /   57       Parkhaus Pfingstweid / Pfingstweidstrasse 1
# 26  open /   84          Parkhaus Stampfenbach / Niklausstrasse 1
# 27  open /    5          Parkhaus Talgarten / Nüschelerstrasse 31
# 28  open /    1           Parkhaus USZ Nord / Frauenklinikstrasse
# 29  open /  411     Parkhaus Uni Irchel / Winterthurerstrasse 181
# 30  open /  101                 Parkhaus Urania / Uraniastrasse 3
# 31  open /   20                Parkhaus Utoquai / Färberstrasse 6
# 32  open /   12     Parkhaus Züri 11 Shopping / Nansenstrasse 5/7
# 33  open /   37           Parkhaus Zürichhorn / Dufourstrasse 142
# 34  open /   32           Parkplatz Eisfeld / Thurgauerstrasse 54
# 35  open /  134   Parkplatz Theater 11 / Dörfli-/Thurgauerstrasse
# 36  open /    0                 Parkplatz USZ Süd / Gloriastrasse
# 37  open /   14           Puls 5 Parkgarage / Giessereistrasse 18

# %% [markdown]
# # Gehen wir zur [Übung 3](https://github.com/MAZ-CAS-DDJ/kurs_18_19/blob/master/06%20APIs%2C%20Scraping%20I/%C3%9Cbung3.ipynb)

# %% [markdown]
# # Komplexere Websites

# %%
#laden wir die Frontpage von Watson
r = requests.get('https://www.watson.ch')
contents = r.text #Wir lesen den Inhalt aus
soup = BeautifulSoup(contents,"html.parser")

# %%
#Ziehen wir die Titel raus
titelliste = soup.find_all('a')

# %%
len(titelliste)
# Out:
# 249

# %%
#Ziehen wir alle Kommentare raus
kommentare = soup.find_all('div', {'class':'standard comments'})

# %%
len(kommentare)
# Out:
# 53

# %% [markdown]
# Hier sehen wir, dass also nicht immer dieselbe Anzahl Kommentare und Artikel herausgelesen werden kann. Nicht jeder Artikel hat einen Kommentar. Wir müssen deshalb unseren Code anpassen.

# %%
storybox = soup.find_all('div', {'class':'text'})

# %%
len(storybox)
# Out:
# 119

# %%
storybox[0]
# Out:
# <div class="text">
#     Wir verwenden Cookies und Analysetools, um die Nutzerfreundlichkeit der Internetseite zu verbessern und passende Werbung von watson und unseren Werbepartnern anzuzeigen.
#     Weitere Infos findest Du in unserer <a href="/u/agb">Datenschutzerklärung</a>.
#     </div>

# %%
storybox[2]
# Out:
# <div class="text">
# <h2><div>Thomas-Cook-Pleite: Briten werden evakuiert, Schweizer müssen selber schauen</div></h2>
# <p class="author">von Kevin Capellini</p>
# <!-- iconrow ==> -->
# <div class="iconrow">
# <!-- media icons ==> -->
# <div class="media_icons">
# <!-- comments ==> -->
# <div class="standard comments">
# <span>4</span>
# </div>
# <!-- <== comments -->
# </div>
# <!-- <== media icons -->
# </div>
# <!-- <== iconrow -->
# </div>

# %%
storybox[2].find('h2').text
# Out:
# 'Thomas-Cook-Pleite: Briten werden evakuiert, Schweizer müssen selber schauen'

# %%
#Diesen Fehler müssen wir auffangen, das tun wir am einfachsten mit try und except.
storybox[2].find('div', {'class':'standard'}).text
# Out:
# '\n4\n'

# %%
lst = []
for elem in storybox:
    try:
        t = elem.find('h2').text
    except:
        t = "N/A" 
    
    try:
        
        k = elem.find('div', {'class':'standard comments'}).text.replace("\n", "")
    except:
        k = "N/A"
    
    mini_dict = {'Titel': t,
                 'Kommentar': k}
    
    lst.append(mini_dict)

# %%
lst
# Out:
# [{'Titel': 'N/A', 'Kommentar': 'N/A'},
#  {'Titel': 'Warum die Demokraten Trump jetzt impeachen müssen',
#   'Kommentar': '1'},
#  {'Titel': 'Thomas-Cook-Pleite: Briten werden evakuiert, Schweizer müssen selber schauen',
#   'Kommentar': '4'},
#  {'Titel': '«Ich habe meine grosse Liebe betrogen…»', 'Kommentar': '8'},
#  {'Titel': 'In der Schweiz öffnet sich seit 2003 die Vermögens-Schere stark',
#   'Kommentar': '24'},
#  {'Titel': 'Fliegender Full Back, schwebender Cornerback und 8 weitere Highlights des NFL-Wochenendes',
#   'Kommentar': '4'},
#  {'Titel': '7 der teuersten Serienflops der TV-Geschichte', 'Kommentar': '14'},
#  {'Titel': 'Schau deine Lieblingsserie auf Amazon Prime, zahle per Handyrechnung und spare Geld!',
#   'Kommentar': 'N/A'},
#  {'Titel': "Wo stand die erste Manor-Filiale der Schweiz? Und wo McDonald's? Die grosse Übersicht",
#   'Kommentar': '9'},
#  {'Titel': '«Love is in the air» – Tenniswelt feiert die «Bromance» zwischen Federer und Nadal',
#   'Kommentar': '14'},
#  {'Titel': 'Ihr Grosi sollte exekutiert werden, lief den Nazis davon – und wird zur Heldin der Emmys',
#   'Kommentar': '2'},
#  {'Titel': 'Neuer Kampfjet: Parlament entscheidet im Überschall-Tempo',
#   'Kommentar': '108'},
#  {'Titel': 'Tests, Tote und Tofranil:  Psychiatrie am Bodensee führte 3000 «Menschenversuche» durch',
#   'Kommentar': 'N/A'},
#  {'Titel': '\nCaptain Xhaka wird bei Arsenal ausgepfiffen – bei seiner Auswechslung gibt’s Applaus\n',
#   'Kommentar': '14'},
#  {'Titel': '\nSchweizer verschwindet auf LSD-Trip im Disneyland – und landet hart wieder in der Realität\n',
#   'Kommentar': '25'},
#  {'Titel': '\nDavid Degen soll FCB-Verwaltungsrat ergänzen +++ Lausanne-Sport bleibt Leader\n',
#   'Kommentar': 'N/A'},
#  {'Titel': "\nPolizei erschiesst 8-Jährige in Favela in Rio – jetzt reicht's den Anwohnern\n",
#   'Kommentar': '4'},
#  {'Titel': '\n«Schwarzer Tag»: Manor schliesst Standort Zürich Bahnhofstrasse Ende Januar 2020\n',
#   'Kommentar': '40'},
#  {'Titel': '\nNach tödlichem Unfall: Züge fahren nur noch mit durchgängig geschlossenen Türen\n',
#   'Kommentar': 'N/A'},
#  {'Titel': '13 interessante Auto-Gadgets, die sich (bisher) nicht richtig durchsetzen konnten',
#   'Kommentar': '21'},
#  {'Titel': 'Buben zeuseln in Auto: Fahrzeug brennt in Winterthur komplett aus',
#   'Kommentar': 'N/A'},
#  {'Titel': '13 Menschen, die in der genetischen Lotterie faszinierende Karten gezogen haben',
#   'Kommentar': '27'},
#  {'Titel': "Die Klimajugend verschickt heute 1'067'000 Klimazeitungen – das steckt dahinter",
#   'Kommentar': '158'},
#  {'Titel': 'Reus tobt: «Das geht mir so auf die Eier, kommt nicht mit eurem Mentalitätsscheiss»',
#   'Kommentar': '18'},
#  {'Titel': 'Ei, was fehlt hier? Birnen-Tiramisu von Swissmilk (ohne Ei)',
#   'Kommentar': 'N/A'},
#  {'Titel': 'FDP-Chefin Petra Gössi attackiert SVP-Bundesrat Guy Parmelin: «Ich erwarte mehr von ihm»',
#   'Kommentar': '46'},
#  {'Titel': 'Sportlerpics auf Social Media: Wer will mit Fanny Stollar wegsegeln?',
#   'Kommentar': '323'},
#  {'Titel': 'Im Bild', 'Kommentar': 'N/A'},
#  {'Titel': 'Videos', 'Kommentar': 'N/A'},
#  {'Titel': '\nDie Schweiz ist um einen Gletscher ärmer\n', 'Kommentar': 'N/A'},
#  {'Titel': '\nÜber 100 Verletzte nach Erdbeben in Albanien\n',
#   'Kommentar': 'N/A'},
#  {'Titel': '\nGedenkanlass für Opfer administrativer Versorgung\n',
#   'Kommentar': 'N/A'},
#  {'Titel': '\n5G-Gegner: «Immer mehr Leute werden leiden.»\n',
#   'Kommentar': 'N/A'},
#  {'Titel': '\n«Se weader is nice» – das englische «th» bereitet Mühe\n',
#   'Kommentar': 'N/A'},
#  {'Titel': '\nJustin Trudeau entschuldigt sich für Foto\n',
#   'Kommentar': 'N/A'},
#  {'Titel': "\n«It's the final countdown»\n", 'Kommentar': 'N/A'},
#  {'Titel': '\nVor dem Insta-Fame kam die «Nahtod-Erfahrung»\n',
#   'Kommentar': 'N/A'},
#  {'Titel': '\nKeine Tabakwerbung mehr – zum Schutz der Minderjährigen\n',
#   'Kommentar': 'N/A'},
#  {'Titel': '\nDas E-Mobil im Test\n', 'Kommentar': 'N/A'},
#  {'Titel': '\nHome-Office stösst dem Chef sauer auf\n', 'Kommentar': 'N/A'},
#  {'Titel': '\nGepimpte VW-Käfer in Äthiopien\n', 'Kommentar': 'N/A'},
#  {'Titel': '\nLandwirtschaftssimulator im E-Sports\n', 'Kommentar': 'N/A'},
#  {'Titel': '\nDänische TV-Show startet Spendenaktion für Bäume\n',
#   'Kommentar': 'N/A'},
#  {'Titel': '\nDrohnenangriff auf die grösste Ölraffinerie Saudi-Arabiens\n',
#   'Kommentar': 'N/A'},
#  {'Titel': '\nTheoretisch bewohnbarer Planet entdeckt\n', 'Kommentar': 'N/A'},
#  {'Titel': '\nCamille Fédérale - Der Röstigraben im Bundeshaus\n',
#   'Kommentar': 'N/A'},
#  {'Titel': '\nViele sehen eine Prostituierte nicht als Mensch\n',
#   'Kommentar': 'N/A'},
#  {'Titel': '\nRap-Video aus der Türkei geht viral\n', 'Kommentar': 'N/A'},
#  {'Titel': 'Meistgelesen', 'Kommentar': 'N/A'},
#  {'Titel': '«Ich habe meine grosse Liebe betrogen…»', 'Kommentar': 'N/A'},
#  {'Titel': 'Thomas-Cook-Pleite: Briten werden evakuiert, Schweizer müssen …',
#   'Kommentar': 'N/A'},
#  {'Titel': 'In der Schweiz öffnet sich seit 2003 die Vermögens-Schere stark',
#   'Kommentar': 'N/A'},
#  {'Titel': '7 der teuersten Serienflops der TV-Geschichte',
#   'Kommentar': 'N/A'},
#  {'Titel': '13 Menschen, die in der genetischen Lotterie faszinierende Karten …',
#   'Kommentar': 'N/A'},
#  {'Titel': 'Meistkommentiert', 'Kommentar': 'N/A'},
#  {'Titel': 'Sportlerpics auf Social Media: Wer will mit Fanny Stollar …',
#   'Kommentar': 'N/A'},
#  {'Titel': "Die Klimajugend verschickt heute 1'067'000 Klimazeitungen – das …",
#   'Kommentar': 'N/A'},
#  {'Titel': 'Neuer Kampfjet: Parlament entscheidet im Überschall-Tempo',
#   'Kommentar': 'N/A'},
#  {'Titel': 'Schluss mit dem «Papiplausch»: Dieses Duo will den …',
#   'Kommentar': 'N/A'},
#  {'Titel': '5G-Gegner erklären die angeblichen Gefahren und präsentieren …',
#   'Kommentar': 'N/A'},
#  {'Titel': 'Meistgeteilt', 'Kommentar': 'N/A'},
#  {'Titel': '«Schwarzer Tag»: Manor schliesst Standort Zürich …',
#   'Kommentar': 'N/A'},
#  {'Titel': "Ja, dieses Bild ist wirklich aus der Schweiz (Nico hat's getestet …",
#   'Kommentar': 'N/A'},
#  {'Titel': 'Wie man das 3. Auge öffnet, den Astralkörper lädt und die DNA …',
#   'Kommentar': 'N/A'},
#  {'Titel': '5G-Gegner demonstrieren in Bern gegen «Zwangsbestrahlung»',
#   'Kommentar': 'N/A'},
#  {'Titel': 'Rick Nash wird wieder Davoser – und meldet sich gleich mit …',
#   'Kommentar': 'N/A'},
#  {'Titel': 'Best of watson', 'Kommentar': 'N/A'},
#  {'Titel': 'Thomas Cooks Pleite und die «grösste Rückführungsaktion seit dem WWII» – …',
#   'Kommentar': '60'},
#  {'Titel': 'Jägerin vs. Straight Edge Veganer: So unterschiedlich kann Tierliebe sein',
#   'Kommentar': '43'},
#  {'Titel': 'Schockierende Beichten – so kriminell sind die watson-Journalisten 😵',
#   'Kommentar': '35'},
#  {'Titel': '13 praktische neue Features für iPhone-User, die niemand kennt, und ein paar Bugs 😏',
#   'Kommentar': '43'},
#  {'Titel': '«In den Industrienationen besteht die grösste Ungleichheit zwischen Jung und Alt.» ',
#   'Kommentar': '29'},
#  {'Titel': 'Essbar oder giftig? Beweise dich im Pilz-Quiz!',
#   'Kommentar': '56'},
#  {'Titel': 'Aus welchen Ländern kommt eigentlich unser Erdöl?',
#   'Kommentar': '46'},
#  {'Titel': "Ja, dieses Bild ist wirklich aus der Schweiz (Nico hat's getestet – und verflucht)",
#   'Kommentar': '59'},
#  {'Titel': 'Ich habe Samsungs Stift-Handy zwei Wochen im Alltag getestet – und das kam dabei heraus',
#   'Kommentar': '17'},
#  {'Titel': 'Letzte Nachrichten', 'Kommentar': 'N/A'},
#  {'Titel': 'Rad-Star Vandenbroucke torkelt aus Disco zum Zmorge und gewinnt danach eine …',
#   'Kommentar': 'N/A'},
#  {'Titel': 'Warum die Demokraten Trump jetzt impeachen müssen',
#   'Kommentar': 'N/A'},
#  {'Titel': 'Tests, Tote und Tofranil:  Psychiatrie am Bodensee führte 3000 …',
#   'Kommentar': 'N/A'},
#  {'Titel': '«Love is in the air» – Tenniswelt feiert die «Bromance» zwischen …',
#   'Kommentar': 'N/A'},
#  {'Titel': '«Ich habe meine grosse Liebe betrogen…»', 'Kommentar': 'N/A'},
#  {'Titel': 'Thomas-Cook-Pleite: Briten werden evakuiert, Schweizer müssen selber …',
#   'Kommentar': 'N/A'},
#  {'Titel': 'Aktuelle Themen', 'Kommentar': 'N/A'},
#  {'Titel': 'Schweiz', 'Kommentar': 'N/A'},
#  {'Titel': 'Luzerner Behörden ermitteln flüchtigen Drogenhändler in Brasilien',
#   'Kommentar': '1'},
#  {'Titel': 'Jetzt ist es soweit: Seit 9.50 Uhr ist der Sommer vorbei',
#   'Kommentar': '7'},
#  {'Titel': 'Was du zur allfälligen Revision des CO2-Gesetzes wissen musst',
#   'Kommentar': '8'},
#  {'Titel': 'International', 'Kommentar': 'N/A'},
#  {'Titel': 'Das waren die Emmys 2019: GoT stellt eigenen Rekord ein – Schweizerin geht …',
#   'Kommentar': '4'},
#  {'Titel': 'Das Rütli der Amerikaner', 'Kommentar': '3'},
#  {'Titel': '«Die Schlacht unserer Leben»: Der Klimawandel treibt Millionen in die Flucht',
#   'Kommentar': '8'},
#  {'Titel': 'Sport', 'Kommentar': 'N/A'},
#  {'Titel': 'Geil or no geil? Bewerte diese 11 Ereignisse des Fussball-Weekends',
#   'Kommentar': '6'},
#  {'Titel': 'Lugano und der Wunsch, so zu werden wie Ambri', 'Kommentar': '7'},
#  {'Titel': 'Europa gewinnt zum 3. Mal – so feiern Federer und Co. den Laver-Cup-Triumph',
#   'Kommentar': '1'},
#  {'Titel': 'Eigentor kostet Dortmund den Sieg in Frankfurt – Liverpool schlägt auch Chelsea',
#   'Kommentar': '4'},
#  {'Titel': 'Delaneys Eigentor kostet Dortmund den Sieg in Frankfurt',
#   'Kommentar': '1'},
#  {'Titel': 'Liverpool bringt den Sieg gegen Chelsea über die Zeit und bleibt makellos',
#   'Kommentar': 'N/A'},
#  {'Titel': 'Leben', 'Kommentar': 'N/A'},
#  {'Titel': '«Ich bin vorsichtiger geworden» - Catherine Deneuve über ihren neuen …',
#   'Kommentar': 'N/A'},
#  {'Titel': '«Game of Thrones» jagt den Emmy-Rekord – doch wir fiebern mit einer Schweizerin mit!',
#   'Kommentar': '1'},
#  {'Titel': 'Mikroplastik überall – doch ist das wirklich ein Problem? ',
#   'Kommentar': '30'},
#  {'Titel': 'Spass', 'Kommentar': 'N/A'},
#  {'Titel': 'QDH: Huber macht, wofür er bekannt ist. Ob du ihn besiegen kannst?',
#   'Kommentar': '83'},
#  {'Titel': 'Du willst einen Oldtimer mit Tesla-Antrieb? Da gibt es eine ganze Reihe ...',
#   'Kommentar': '72'},
#  {'Titel': '«Friends» wird 25 – und auch die Schauspieler sind älter geworden (und wie 😱)',
#   'Kommentar': '22'},
#  {'Titel': 'Digital', 'Kommentar': 'N/A'},
#  {'Titel': 'VW baut jetzt seine eigenen Akkus für Elektroautos, aber ...',
#   'Kommentar': 'N/A'},
#  {'Titel': 'So robust ist das neue Galaxy Fold von Samsung wirklich',
#   'Kommentar': '3'},
#  {'Titel': '5G-Gegner erklären die angeblichen Gefahren und präsentieren ihre Lösungsansätze',
#   'Kommentar': '137'},
#  {'Titel': 'Wissen', 'Kommentar': 'N/A'},
#  {'Titel': 'Die schweizerische Krankheit – Heimweh nach den Bergen',
#   'Kommentar': '20'},
#  {'Titel': 'Was ist das für ein seltsames 12-beiniges Tier?',
#   'Kommentar': '6'},
#  {'Titel': 'Wenn die Stimme den Verbrecher entlarvt – und warum das problematisch sein kann',
#   'Kommentar': '3'},
#  {'Titel': 'Blogs', 'Kommentar': 'N/A'},
#  {'Titel': 'Wie man das 3. Auge öffnet, den Astralkörper lädt und die DNA erweitert …',
#   'Kommentar': '80'},
#  {'Titel': '«Eine Kuh macht mein Auto kaputt und ich muss einen Teil bezahlen. Wieso?»',
#   'Kommentar': '39'},
#  {'Titel': 'Eins vor Tod will ich Sex und (eventuell) eine Ohrfeige',
#   'Kommentar': '187'}]

# %%
pd.DataFrame(lst)
# Out:
#     Kommentar                                              Titel
# 0         N/A                                                N/A
# 1           1  Warum die Demokraten Trump jetzt impeachen müssen
# 2           4  Thomas-Cook-Pleite: Briten werden evakuiert, S...
# 3           8            «Ich habe meine grosse Liebe betrogen…»
# 4          24  In der Schweiz öffnet sich seit 2003 die Vermö...
# 5           4  Fliegender Full Back, schwebender Cornerback u...
# 6          14      7 der teuersten Serienflops der TV-Geschichte
# 7         N/A  Schau deine Lieblingsserie auf Amazon Prime, z...
# 8           9  Wo stand die erste Manor-Filiale der Schweiz? ...
# 9          14  «Love is in the air» – Tenniswelt feiert die «...
# 10          2  Ihr Grosi sollte exekutiert werden, lief den N...
# 11        108  Neuer Kampfjet: Parlament entscheidet im Übers...
# 12        N/A  Tests, Tote und Tofranil:  Psychiatrie am Bode...
# 13         14  \nCaptain Xhaka wird bei Arsenal ausgepfiffen ...
# 14         25  \nSchweizer verschwindet auf LSD-Trip im Disne...
# 15        N/A  \nDavid Degen soll FCB-Verwaltungsrat ergänzen...
# 16          4  \nPolizei erschiesst 8-Jährige in Favela in Ri...
# 17         40  \n«Schwarzer Tag»: Manor schliesst Standort Zü...
# 18        N/A  \nNach tödlichem Unfall: Züge fahren nur noch ...
# 19         21  13 interessante Auto-Gadgets, die sich (bisher...
# 20        N/A  Buben zeuseln in Auto: Fahrzeug brennt in Wint...
# 21         27  13 Menschen, die in der genetischen Lotterie f...
# 22        158  Die Klimajugend verschickt heute 1'067'000 Kli...
# 23         18  Reus tobt: «Das geht mir so auf die Eier, komm...
# 24        N/A  Ei, was fehlt hier? Birnen-Tiramisu von Swissm...
# 25         46  FDP-Chefin Petra Gössi attackiert SVP-Bundesra...
# 26        323  Sportlerpics auf Social Media: Wer will mit Fa...
# 27        N/A                                            Im Bild
# 28        N/A                                             Videos
# 29        N/A       \nDie Schweiz ist um einen Gletscher ärmer\n
# ..        ...                                                ...
# 89          4  Das waren die Emmys 2019: GoT stellt eigenen R...
# 90          3                           Das Rütli der Amerikaner
# 91          8  «Die Schlacht unserer Leben»: Der Klimawandel ...
# 92        N/A                                              Sport
# 93          6  Geil or no geil? Bewerte diese 11 Ereignisse d...
# 94          7      Lugano und der Wunsch, so zu werden wie Ambri
# 95          1  Europa gewinnt zum 3. Mal – so feiern Federer ...
# 96          4  Eigentor kostet Dortmund den Sieg in Frankfurt...
# 97          1  Delaneys Eigentor kostet Dortmund den Sieg in ...
# 98        N/A  Liverpool bringt den Sieg gegen Chelsea über d...
# 99        N/A                                              Leben
# 100       N/A  «Ich bin vorsichtiger geworden» - Catherine De...
# 101         1  «Game of Thrones» jagt den Emmy-Rekord – doch ...
# 102        30  Mikroplastik überall – doch ist das wirklich e...
# 103       N/A                                              Spass
# 104        83  QDH: Huber macht, wofür er bekannt ist. Ob du ...
# 105        72  Du willst einen Oldtimer mit Tesla-Antrieb? Da...
# 106        22  «Friends» wird 25 – und auch die Schauspieler ...
# 107       N/A                                            Digital
# 108       N/A  VW baut jetzt seine eigenen Akkus für Elektroa...
# 109         3  So robust ist das neue Galaxy Fold von Samsung...
# 110       137  5G-Gegner erklären die angeblichen Gefahren un...
# 111       N/A                                             Wissen
# 112        20  Die schweizerische Krankheit – Heimweh nach de...
# 113         6    Was ist das für ein seltsames 12-beiniges Tier?
# 114         3  Wenn die Stimme den Verbrecher entlarvt – und ...
# 115       N/A                                              Blogs
# 116        80  Wie man das 3. Auge öffnet, den Astralkörper l...
# 117        39  «Eine Kuh macht mein Auto kaputt und ich muss ...
# 118       187  Eins vor Tod will ich Sex und (eventuell) eine...
#
# [119 rows x 2 columns]

# %% [markdown]
# # Als Übung: Mit Funktion dasselbe tun.
# Wenn man sehr ausführlichen Code entwickelt, ist es oft praktisch, mit Funktionen zu arbeiten. Hier ein Beispiel davon, wie das aussehen könnte.

# %%
def kommentarezählen(url):
    
    r = requests.get(url)
    soup = BeautifulSoup(r.text,'xml')
    storybox = soup.find_all('div', {'class':'text'})
    
    lst = []   
    for elem in storybox:
        try: #Hier kannn man mit Fehlern umgehen. Man muss allerdings spärlcih damit umgehen. 
            t = elem.find('h2').text
        except:
            t = 'Kein Titel'
        try:
            k = elem.find('div', {'class':'standard comments'}).text.replace("\n", "")
        except:
            k = 'Keine Kommentare'
        mini_dict = {'Titel': t,
                 'Kommentar': k}
        lst.append(mini_dict)
    
    return pd.DataFrame(lst)

# %%
kommentarezählen('https://www.watson.ch/')
# Out:
#             Kommentar                                              Titel
# 0    Keine Kommentare                                         Kein Titel
# 1                   1  Warum die Demokraten Trump jetzt impeachen müssen
# 2                   4  Thomas-Cook-Pleite: Briten werden evakuiert, S...
# 3                   8            «Ich habe meine grosse Liebe betrogen…»
# 4                  24  In der Schweiz öffnet sich seit 2003 die Vermö...
# 5                   4  Fliegender Full Back, schwebender Cornerback u...
# 6                  14      7 der teuersten Serienflops der TV-Geschichte
# 7    Keine Kommentare  Schau deine Lieblingsserie auf Amazon Prime, z...
# 8                   9  Wo stand die erste Manor-Filiale der Schweiz? ...
# 9                  14  «Love is in the air» – Tenniswelt feiert die «...
# 10                  2  Ihr Grosi sollte exekutiert werden, lief den N...
# 11                108  Neuer Kampfjet: Parlament entscheidet im Übers...
# 12   Keine Kommentare  Tests, Tote und Tofranil:  Psychiatrie am Bode...
# 13                 14  \nCaptain Xhaka wird bei Arsenal ausgepfiffen ...
# 14                 25  \nSchweizer verschwindet auf LSD-Trip im Disne...
# 15   Keine Kommentare  \nDavid Degen soll FCB-Verwaltungsrat ergänzen...
# 16                  4  \nPolizei erschiesst 8-Jährige in Favela in Ri...
# 17                 40  \n«Schwarzer Tag»: Manor schliesst Standort Zü...
# 18   Keine Kommentare  \nNach tödlichem Unfall: Züge fahren nur noch ...
# 19                 21  13 interessante Auto-Gadgets, die sich (bisher...
# 20   Keine Kommentare  Buben zeuseln in Auto: Fahrzeug brennt in Wint...
# 21                 27  13 Menschen, die in der genetischen Lotterie f...
# 22                158  Die Klimajugend verschickt heute 1'067'000 Kli...
# 23                 18  Reus tobt: «Das geht mir so auf die Eier, komm...
# 24   Keine Kommentare  Ei, was fehlt hier? Birnen-Tiramisu von Swissm...
# 25                 46  FDP-Chefin Petra Gössi attackiert SVP-Bundesra...
# 26                323  Sportlerpics auf Social Media: Wer will mit Fa...
# 27   Keine Kommentare                                            Im Bild
# 28   Keine Kommentare                                             Videos
# 29   Keine Kommentare       \nDie Schweiz ist um einen Gletscher ärmer\n
# ..                ...                                                ...
# 89                  4  Das waren die Emmys 2019: GoT stellt eigenen R...
# 90                  3                           Das Rütli der Amerikaner
# 91                  8  «Die Schlacht unserer Leben»: Der Klimawandel ...
# 92   Keine Kommentare                                              Sport
# 93                  6  Geil or no geil? Bewerte diese 11 Ereignisse d...
# 94                  7      Lugano und der Wunsch, so zu werden wie Ambri
# 95                  1  Europa gewinnt zum 3. Mal – so feiern Federer ...
# 96                  4  Eigentor kostet Dortmund den Sieg in Frankfurt...
# 97                  1  Delaneys Eigentor kostet Dortmund den Sieg in ...
# 98   Keine Kommentare  Liverpool bringt den Sieg gegen Chelsea über d...
# 99   Keine Kommentare                                              Leben
# 100  Keine Kommentare  «Ich bin vorsichtiger geworden» - Catherine De...
# 101                 1  «Game of Thrones» jagt den Emmy-Rekord – doch ...
# 102                30  Mikroplastik überall – doch ist das wirklich e...
# 103  Keine Kommentare                                              Spass
# 104                83  QDH: Huber macht, wofür er bekannt ist. Ob du ...
# 105                72  Du willst einen Oldtimer mit Tesla-Antrieb? Da...
# 106                22  «Friends» wird 25 – und auch die Schauspieler ...
# 107  Keine Kommentare                                            Digital
# 108  Keine Kommentare  VW baut jetzt seine eigenen Akkus für Elektroa...
# 109                 3  So robust ist das neue Galaxy Fold von Samsung...
# 110               137  5G-Gegner erklären die angeblichen Gefahren un...
# 111  Keine Kommentare                                             Wissen
# 112                20  Die schweizerische Krankheit – Heimweh nach de...
# 113                 6    Was ist das für ein seltsames 12-beiniges Tier?
# 114                 3  Wenn die Stimme den Verbrecher entlarvt – und ...
# 115  Keine Kommentare                                              Blogs
# 116                80  Wie man das 3. Auge öffnet, den Astralkörper l...
# 117                39  «Eine Kuh macht mein Auto kaputt und ich muss ...
# 118               187  Eins vor Tod will ich Sex und (eventuell) eine...
#
# [119 rows x 2 columns]

# %% [markdown]
# Das können wir natürlich auf der Kommandozeile auslösen. Speichern wir unsere Skript und wandeln wir ihn um. (Wir müssen noch dafür sorgen, dass er mit einem Parameter ausgestattet werden kann. Aber auch das lässt sich einfach googeln).

# %% [markdown]
# # Nun üben wir das ein wenig: Weiter zu Übung 4
