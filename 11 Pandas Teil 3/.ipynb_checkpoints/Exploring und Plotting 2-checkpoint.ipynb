# %% [markdown]
# # Exploring und Plotting 2

# %% [markdown]
# **Inhalt:** Selbständige Übung in Gruppen
#
# **Nötige Skills:** Time Series
#
# **Lernziele:**
# - Selbständig Daten explorieren und Storyideen testen

# %% [markdown]
# # Das Beispiel

# %% [markdown]
# Börsenkurse aller Bluechips-Firmen an der Schweizer Börse.
#
# Korpus: https://www.six-group.com/exchanges/shares/explorer/swiss_blue_chips/closings_de.html
#
# Die Daten stammen von dieser Quelle: https://finance.yahoo.com/ und wurden zu einem File kompiliert.
#
# Kompilierungsfile: `dataprojects/Boersenkurse/Börsenkurse kompilieren.ipnyb`
#
# Kompilierte Daten: `dataprojects/Boersenkurse/smi_members.csv`

# %% [markdown]
# ## Vorbereitung

# %% [markdown]
# Entscheiden Sie selbst, welche Libraries Sie brauchen!

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
from datetime import datetime

# %% [markdown]
# ## Datenfile laden

# %% [markdown]
# Wie ist die Datei strukturiert? Was müssen wir beim Laden beachten?
#
# Tipp: `index_col=0` verwenden.

# %%
path = "dataprojects/Boersenkurse/smi_members.csv"

# %%
df = pd.read_csv(path, index_col = 0)

# %%
df.index = pd.to_datetime(df.index)
df
# Out:
#               ABB LTD     ADECCO      ALCON        AMS   CLARIANT   CS GROUP  \
# 2014-10-13  19.650000  60.400002        NaN        NaN  15.540000  23.689699
# 2014-10-14  19.760000  60.700001        NaN        NaN  15.580000  23.689699
# 2014-10-15  19.160000  58.849998        NaN        NaN  15.160000  22.817499
# 2014-10-16  19.260000  59.500000        NaN        NaN  15.060000  22.292299
# 2014-10-17  19.400000  60.950001        NaN        NaN  15.380000  22.751900
# ...               ...        ...        ...        ...        ...        ...
# 2019-10-07  18.070000  54.139999  56.840000  44.369999  19.825001  11.475000
# 2019-10-08  17.889999  53.220001  56.020000  42.029999  19.610001  11.405000
# 2019-10-09  17.915001  53.439999  55.790001  42.549999  19.745001  11.420000
# 2019-10-10  18.125000  54.119999  56.060001  42.970001  20.150000  11.610000
# 2019-10-11  18.475000  56.139999  56.200001  44.259998  20.690001  12.055000
#
#                GEBERIT  GIVAUDAN  JULIUS BAER  KUEHNE+NAGEL INT  ...  \
# 2014-10-13  289.799988    1461.0    39.500000        117.300003  ...
# 2014-10-14  294.399994    1478.0    39.770000        118.400002  ...
# 2014-10-15  288.000000    1458.0    37.459999        115.900002  ...
# 2014-10-16  288.000000    1466.0    37.509998        117.099998  ...
# 2014-10-17  297.200012    1494.0    39.119999        117.500000  ...
# ...                ...       ...          ...               ...  ...
# 2019-10-07  464.799988    2760.0    41.790001        147.750000  ...
# 2019-10-08  459.100006    2733.0    41.410000        145.250000  ...
# 2019-10-09  460.299988    2737.0    41.389999        146.550003  ...
# 2019-10-10  466.000000    2795.0    42.240002        148.949997  ...
# 2019-10-11  472.799988    2840.0    44.139999        151.800003  ...
#
#                   SIKA      SONOVA  SWATCH GROUP  SWISS LIFE HOLDING  \
# 2014-10-13   51.849998  143.899994    436.100006          211.899994
# 2014-10-14   52.716702  138.399994    435.299988          211.100006
# 2014-10-15   51.799999  134.600006    429.500000          205.699997
# 25%    ...    60.483351   130.800003    301.100006          239.699997
# 50%    ...   101.667000   146.500000    360.600006          322.700012
# 75%    ...   130.375000   170.650002    400.149994          353.699997
# max    ...   167.800003   234.199997    498.100006          495.899994
#
#           SWISS RE     SWISSCOM      TEMENOS    UBS GROUP        VIFOR  \
# count  1254.000000  1255.000000  1255.000000  1255.000000  1255.000000
# mean     90.266699   487.712112    90.790956    15.802676   125.032271
# std       5.592158    35.893635    47.821762     2.572662    25.497484
# min      71.050003   428.600006    26.700001     9.940000    71.599998
# 25%      86.720001   459.799988    48.125000    13.770000   107.099998
# 50%      90.145001   482.100006    79.650002    15.960000   126.000000
# 75%      94.395001   510.000000   131.200005    17.150000   142.500000
# max     104.250000   586.500000   183.350006    22.500000   191.000000
#
#        ZURICH INSURANCE
# count       1255.000000
# mean         288.744462
# std           34.860818
# min          196.000000
# 25%          266.550003
# 50%          294.299988
# 75%          309.200012
# max          388.799988
#
# [8 rows x 30 columns]

# %%
df.dtypes
# Out:
# ABB LTD               float64
# ADECCO                float64
# ALCON                 float64
# AMS                   float64
# CLARIANT              float64
# CS GROUP              float64
# GEBERIT               float64
# GIVAUDAN              float64
# JULIUS BAER           float64
# KUEHNE+NAGEL INT      float64
# LAFARGEHOLCIM         float64
# LOGITECH              float64
# LONZA                 float64
# NESTLE                float64
# NOVARTIS              float64
# PARTNERS GROUP        float64
# RICHEMONT             float64
# ROCHE                 float64
# SCHINDLER             float64
# SGS                   float64
# SIKA                  float64
# SONOVA                float64
# SWATCH GROUP          float64
# SWISS LIFE HOLDING    float64
# SWISS RE              float64
# SWISSCOM              float64
# TEMENOS               float64
# UBS GROUP             float64
# VIFOR                 float64
# ZURICH INSURANCE      float64
# dtype: object

# %%
df.shape
# Out:
# (1255, 30)

# %% [markdown]
# ## Explorieren

# %% [markdown]
# Ihr Ziel ist, aus den Börsendaten eine einfache Story zu generieren.
#
# Überlegen Sie sich dazu:
# - Was sind mögliche interessante Fragen?
# - Welche Auswertungen sind nötig, um die Fragen zu beanworten?
# - Wie stellen Sie die Resultate mittels Grafiken dar?
#
# Arbeiten Sie in Gruppen, um ein Ergebnis zu erarbeiten!

# %%
df
# Out:
#               ABB LTD     ADECCO      ALCON        AMS   CLARIANT   CS GROUP  \
# 2014-10-13  19.650000  60.400002        NaN        NaN  15.540000  23.689699
# 2014-10-14  19.760000  60.700001        NaN        NaN  15.580000  23.689699
# 2014-10-15  19.160000  58.849998        NaN        NaN  15.160000  22.817499
# 2014-10-16  19.260000  59.500000        NaN        NaN  15.060000  22.292299
# 2014-10-17  19.400000  60.950001        NaN        NaN  15.380000  22.751900
# ...               ...        ...        ...        ...        ...        ...
# 2019-10-07  18.070000  54.139999  56.840000  44.369999  19.825001  11.475000
# 2019-10-08  17.889999  53.220001  56.020000  42.029999  19.610001  11.405000
# 2019-10-09  17.915001  53.439999  55.790001  42.549999  19.745001  11.420000
# 2019-10-10  18.125000  54.119999  56.060001  42.970001  20.150000  11.610000
# 2019-10-11  18.475000  56.139999  56.200001  44.259998  20.690001  12.055000
#
#                GEBERIT  GIVAUDAN  JULIUS BAER  KUEHNE+NAGEL INT  ...  \
# 2019-07-01 -0.014051 -0.035953  0.021926  0.319397  0.009737  0.047944
# 2019-08-01 -0.043236 -0.060303 -0.021569 -0.040363 -0.080427 -0.074018
# 2019-09-01  0.083069  0.066367  0.011503  0.044372  0.104760  0.110165
# 2019-10-01 -0.066173 -0.018934 -0.045995 -0.020027  0.011943 -0.066935
#
#              GEBERIT  GIVAUDAN  JULIUS BAER  KUEHNE+NAGEL INT  ...      SIKA  \
# 2014-10-01       NaN       NaN          NaN               NaN  ...       NaN
# 2014-11-01  0.081492  0.075084     0.080326          0.062344  ...  0.098170
# 2014-12-01  0.019194  0.080518     0.038228          0.038386  ... -0.117172
# 2015-01-01 -0.033123 -0.015245    -0.092450         -0.035909  ... -0.059087
# 2015-02-01 -0.004152  0.023634     0.075744          0.043652  ...  0.087627
# ...              ...       ...          ...               ...  ...       ...
# 2019-06-01  0.009639  0.053499    -0.055610          0.000757  ...  0.038736
# 2019-07-01  0.006406 -0.018543     0.033646          0.068661  ... -0.025267
# 2019-08-01 -0.042687 -0.040614    -0.104158         -0.033341  ... -0.108295
# 2019-09-01  0.067088  0.060302     0.117079          0.048332  ...  0.054655
# 2019-10-01 -0.011896 -0.000473    -0.016750         -0.003917  ...  0.032571
#
#               SONOVA  SWATCH GROUP  SWISS LIFE HOLDING  SWISS RE  SWISSCOM  \
# 2014-10-01       NaN           NaN                 NaN       NaN       NaN
# 2014-11-01  0.041314      0.037756            0.038569  0.088017  0.067340
# 2014-12-01 -0.027193     -0.009319            0.042470  0.034218 -0.020883
# 2015-01-01 -0.086786     -0.134472           -0.047189 -0.016863 -0.064319
# 2015-02-01 -0.040396      0.055288            0.015641  0.038808  0.029747
# ...              ...           ...                 ...       ...       ...
# 2019-06-01  0.064574     -0.041859            0.035576  0.054929  0.028311
# 2019-07-01 -0.009914      0.088162            0.033633 -0.008853 -0.014345
# 2019-08-01  0.013997     -0.075969           -0.047188 -0.002562 -0.003458
# 2019-09-01 -0.007928      0.009345            0.030466  0.042475  0.014931
# 2019-10-01  0.018215     -0.054477           -0.024910  0.010504  0.014472
#
#              TEMENOS  UBS GROUP     VIFOR  ZURICH INSURANCE
# 2014-10-01       NaN        NaN       NaN               NaN
# 2014-11-01  0.026442   0.078780  0.045474          0.051272
# 2014-12-01  0.030136   0.027761 -0.008936          0.039829
# 2015-01-01 -0.111726  -0.091601 -0.041481         -0.005358
# 2015-02-01  0.036678   0.032424  0.010278          0.014329
# ...              ...        ...       ...               ...
# 2019-06-01  0.021818  -0.051824  0.020548          0.041163
# 2019-07-01 -0.005267   0.017733  0.039667          0.030374
# 2019-08-01 -0.068187  -0.118676  0.056430         -0.002213
# 2019-09-01  0.027787   0.071633  0.034361          0.081731
# 2019-10-01 -0.025429  -0.034007 -0.001520          0.012603
#
# [61 rows x 30 columns]

# %%
df_volatil = df_change[(df_change >= 0.05)|(df_change <= -0.05)]

# %%
df_volatil
# Out:
#              ABB LTD    ADECCO  ALCON       AMS  CLARIANT  CS GROUP   GEBERIT  \
# 2014-10-01       NaN       NaN    NaN       NaN       NaN       NaN       NaN
# 2014-11-01  0.079790  0.051791    NaN       NaN  0.094140       NaN  0.081492
# 2014-12-01       NaN       NaN    NaN       NaN       NaN       NaN       NaN
# 2015-01-01 -0.108811       NaN    NaN       NaN -0.088626 -0.162785       NaN
# 2015-02-01  0.052712  0.098208    NaN       NaN  0.073157       NaN       NaN
# ...              ...       ...    ...       ...       ...       ...       ...
# 2019-06-01       NaN       NaN    NaN -0.175920       NaN -0.052869       NaN
# 2019-07-01       NaN       NaN    NaN  0.319397       NaN       NaN       NaN
# 2019-08-01       NaN -0.060303    NaN       NaN -0.080427 -0.074018       NaN
# 2019-09-01  0.083069  0.066367    NaN       NaN  0.104760  0.110165  0.067088
# 2019-10-01 -0.066173       NaN    NaN       NaN       NaN -0.066935       NaN
#
#             GIVAUDAN  JULIUS BAER  KUEHNE+NAGEL INT  ...      SIKA    SONOVA  \
# 2014-10-01       NaN          NaN               NaN  ...       NaN       NaN
# 2014-11-01  0.075084     0.080326          0.062344  ...  0.098170       NaN
# 2014-12-01  0.080518          NaN               NaN  ... -0.117172       NaN
# 2015-01-01       NaN    -0.092450               NaN  ... -0.059087 -0.086786
# 2015-02-01       NaN     0.075744               NaN  ...  0.087627       NaN
# ...              ...          ...               ...  ...       ...       ...
# 2019-06-01  0.053499    -0.055610               NaN  ...       NaN  0.064574
# 2019-07-01       NaN          NaN          0.068661  ...       NaN       NaN
# 2019-08-01       NaN    -0.104158               NaN  ... -0.108295       NaN
# 2019-09-01  0.060302     0.117079               NaN  ...  0.054655       NaN
# 2019-10-01       NaN          NaN               NaN  ...       NaN       NaN
#
#             SWATCH GROUP  SWISS LIFE HOLDING  SWISS RE  SWISSCOM   TEMENOS  \
# 2014-10-01           NaN                 NaN       NaN       NaN       NaN
# 2014-11-01           NaN                 NaN  0.088017  0.067340       NaN
# 2014-12-01           NaN                 NaN       NaN       NaN       NaN
# 2015-01-01     -0.134472                 NaN       NaN -0.064319 -0.111726
# 2015-02-01      0.055288                 NaN       NaN       NaN       NaN
# ...                  ...                 ...       ...       ...       ...
# 2019-06-01           NaN                 NaN  0.054929       NaN       NaN
# 2019-07-01      0.088162                 NaN       NaN       NaN       NaN
# 2019-08-01     -0.075969                 NaN       NaN       NaN -0.068187
# 2019-09-01           NaN                 NaN       NaN       NaN       NaN
# 2019-10-01     -0.054477                 NaN       NaN       NaN       NaN
#
#             UBS GROUP    VIFOR  ZURICH INSURANCE
# 2014-10-01        NaN      NaN               NaN
# 2014-11-01   0.078780      NaN          0.051272
# 2014-12-01        NaN      NaN               NaN
# 2015-01-01  -0.091601      NaN               NaN
# 2015-02-01        NaN      NaN               NaN
# ...               ...      ...               ...
# 2019-06-01  -0.051824      NaN               NaN
# 2019-07-01        NaN      NaN               NaN
# 2019-08-01  -0.118676  0.05643               NaN
# 2019-09-01   0.071633      NaN          0.081731
# 2019-10-01        NaN      NaN               NaN
#
# [61 rows x 30 columns]

# %%
df_volatil.count().sort_values(ascending=False).plot(kind="bar", figsize=(10,5))

# %%
performance = df.iloc[-1]/df.iloc[-0]
performance
# Out:
# ABB LTD               0.940204
# ADECCO                0.929470
# ALCON                      NaN
# AMS                        NaN
# CLARIANT              1.331403
# CS GROUP              0.508871
# GEBERIT               1.631470
# GIVAUDAN              1.943874
# JULIUS BAER           1.117468
# KUEHNE+NAGEL INT      1.294118
# LAFARGEHOLCIM         0.790873
# LOGITECH                   NaN
# LONZA                 3.324854
# NESTLE                1.565689
# NOVARTIS              1.169549
# PARTNERS GROUP        3.240152
# RICHEMONT             0.947272
# ROCHE                 1.095418
# SCHINDLER             1.813008
# SGS                   1.319274
# SIKA                  3.033751
# SONOVA                1.580959
# SWATCH GROUP          0.602614
# SWISS LIFE HOLDING    2.275130
# SWISS RE              1.405974
# SWISSCOM              0.952023
# TEMENOS               5.345313
# UBS GROUP             0.725817
# VIFOR                 2.094694
# ZURICH INSURANCE      1.393548
# dtype: float64

# %%
volatile_monate = df_volatil.count()
volatile_monate
# Out:
# ABB LTD               20
# ADECCO                28
# ALCON                  0
# AMS                    3
# CLARIANT              24
# CS GROUP              28
# GEBERIT               11
# GIVAUDAN              11
# JULIUS BAER           25
# KUEHNE+NAGEL INT      13
# LAFARGEHOLCIM         25
# LOGITECH               3
# LONZA                 19
# NESTLE                 7
# NOVARTIS               9
# PARTNERS GROUP        18
# RICHEMONT             23
# ROCHE                  8
# SCHINDLER             13
# SGS                   11
# SIKA                  24
# SONOVA                20
# SWATCH GROUP          32
# SWISS LIFE HOLDING    16
# SWISS RE               9
# SWISSCOM               7
# TEMENOS               30
# UBS GROUP             24
# VIFOR                 28
# ZURICH INSURANCE      11
# dtype: int64

# %%
relativiert = volatile_monate/performance
relativiert.sort_values(ascending = False).plot(kind="bar", figsize=(10,5), title = "Risikoanalyse: Volatilität, Performance-bereinigt (negative Ausschläge zählen mehr)")

# %%
# neuer Versuch: positive und negative Werte im gleichen Bar-Chart:

# %%
df_volatil.count().sort_values(ascending=False).plot(kind="bar", figsize=(10,5))

# %%
df_volatil_positiv = df_change[df_change >= 0.05]
df_volatil_negativ = df_change[df_change <= -0.05]

# %%
monate_negativ = (df_volatil_negativ.count()) * -1

# %%
monate_positiv = df_volatil_positiv.count()

# %%
#Jetzt verwandeln wir die Pandas-Series in drei Listen: den Index und die Anzahl poitiver und negativer Monate.
liste_firmen = monate_positiv.index.tolist()
liste_positiv = monate_positiv.tolist()
liste_negativ = monate_negativ.tolist()

# %%
#daraus machen wir ein Dictionary
dictionary = {"Firmen": liste_firmen, "+": liste_positiv, "-": liste_negativ}

# %%
#und daraus wieder eine Dataframe
df = pd.DataFrame(dictionary)

# %%
df.plot(kind="bar", x="Firmen", figsize=(15,10) )

# %%
#Jetzt wollen wir das noch sauber sortieren. Dazu zuerst in einer neuen Spalte die Bandbreite bestimmen:
df["Bandbreite"] = df["+"]-df["-"]
df.head(5)
# Out:
#      Firmen   +   -  Bandbreite
# 0   ABB LTD  10 -10          20
# 1    ADECCO  13 -15          28
# 2     ALCON   0   0           0
# 3       AMS   2  -1           3
# 4  CLARIANT  13 -11          24

# %%
df.sort_values("Bandbreite", ascending = False).plot(kind="bar", x="Firmen", y= ["+", "-"], figsize=(15,10) )

# %% [markdown]
# ## Die Story
# Wählen Sie eine ihrer Fragen aus, die Sie bearbeitet haben.
# - Drei bis vier Sätze, welche die Story zusammenfassen
# - eine oder mehrere Grafiken, die das Ergebnis illustrieren
