# %% [markdown]
# https://towardsdatascience.com/named-entity-recognition-with-nltk-and-spacy-8c4a7d88e7da

# %%
#!pip install spacy
#!python -m spacy download en_core_web_sm

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm     #hier...
nlp = en_core_web_sm.load()   #... und hier lädt spacy einen Datensatz runter, um damit zu trainieren

# %%
article  = '''

Air pollution is a very big deal. Its adverse effects on numerous health outcomes and general mortality are widely documented. However, our understanding of its cognitive costs is more recent and those costs are almost certainly still significantly under-emphasized. For example, cognitive effects are not mentioned in most EPA materials.

World Bank data indicate that 3.7 billion people, about half the world's population, are exposed to more than 50 µg/m³ of PM2.5 on an annual basis, 5x the unit of measure for most of the findings below.

    Chess players make more mistakes on polluted days: "We find that an increase of 10 µg/m³ raises the probability of making an error by 1.5 percentage points, and increases the magnitude of the errors by 9.4%. The impact of pollution is exacerbated by time pressure. When players approach the time control of games, an increase of 10 µg/m³, corresponding to about one standard deviation, increases the probability of making a meaningful error by 3.2 percentage points, and errors being 17.3% larger." – Künn et al 2019.
    A 3.26x (albeit with very wide CI) increase in Alzheimer's incidence for each 10 µg/m³ increase in long-term PM2.5 exposure? "Short- and long-term PM2.5 exposure was associated with increased risks of stroke (short-term odds ratio 1.01 [per µg/m³ increase in PM2.5 concentrations], 95% CI 1.01-1.02; long-term 1.14, 95% CI 1.08-1.21) and mortality (short-term 1.02, 95% CI 1.01-1.04; long-term 1.15, 95% CI 1.07-1.24) of stroke. Long-term PM2.5 exposure was associated with increased risks of dementia (1.16, 95% CI 1.07-1.26), Alzheimer's disease (3.26, 95% 0.84-12.74), ASD (1.68, 95% CI 1.20-2.34), and Parkinson's disease (1.34, 95% CI 1.04-1.73)." – Fu et al 2019. Similar effects are seen in Bishop et al 2018: "We find that a 1 µg/m³ increase in decadal PM2.5 increases the probability of a dementia diagnosis by 1.68 percentage points."
    A study of 20,000 elderly women concluded that "the effect of a 10 µg/m³ increment in long-term [PM2.5 and PM10] exposure is cognitively equivalent to aging by approximately 2 years". – Weuve et al 2013.
    "Utilizing variations in transitory and cumulative air pollution exposures for the same individuals over time in China, we provide evidence that polluted air may impede cognitive ability as people become older, especially for less educated men. Cutting annual mean concentration of particulate matter smaller than 10 µm (PM10) in China to the Environmental Protection Agency’s standard (50 µg/m³) would move people from the median to the 63rd percentile (verbal test scores) and the 58th percentile (math test scores), respectively." – Zhang et al 2018.
    Stock market returns are lower on polluted days. "This estimate indicates that a one unit increase in PM2.5 decreases the daily percentage returns by 1.7%. Put differently, a one standard deviation increase in PM2.5 decreases the daily percentage returns by 11.9%, a substantial effect on daily NYSE returns." Hayes et al 2016.
    Baseball umpires make worse decisions on polluted days. "Unique characteristics of this setting combined with high-frequency data disentangle effects of multiple pollutants and identify previously under-explored acute effects. We find a 1 ppm increase in 3 hour CO causes an 11.5% increase in the propensity of umpires to make incorrect calls and a 10 µg/m³ increase in 12-hour PM2.5 causes a 2.6% increase." Archsmith et al 2018.
    Politicians use less complex speech on polluted days. "We apply textual analysis to convert over 100,000 verbal statements made by Canadian MPs from 2006 through 2011 into—among other metrics—speech-specific Flesch-Kincaid grade-level indices. This index measures the complexity of an MP’s speech by the number of years of education needed to accurately understand it. Conditioning on individual fixed effects and other controls, we show that elevated levels of airborne fine particulate matter reduce the complexity of MPs’s speeches. A high-pollution day, defined as daily average PM2.5 concentrations greater than 15 µg/m³, causes a 2.3% reduction in same-day speech quality. To put this into perspective, this is equivalent to the removal of 2.6 months of education." Heyes et al 2019.
    "Exposure to CO2 and VOCs at levels found in conventional office buildings was associated with lower cognitive scores than those associated with levels of these compounds found in a Green building." – Allen et al 2016. The effect seems to kick in at around 1,000 ppm of CO2.

'''

# %% [markdown]
# ## Mit Spacy NLP verarbeiten

# %%
article = nlp(article)
len(article.ents) #Anzahl der Entitäten
# Out:
# 91

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'ORG': 5,
#          'CARDINAL': 25,
#          'DATE': 24,
#          'QUANTITY': 4,
#          'PERCENT': 15,
#          'MONEY': 2,
#          'PERSON': 5,
#          'GPE': 6,
#          'ORDINAL': 1,
#          'TIME': 1,
#          'NORP': 1,
#          'WORK_OF_ART': 2})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('95%', 8), ('polluted days', 3), ('daily', 3)]

# %%
sentences = [x for x in article.sents]
#print(sentences[2])
sentences[3]
# Out:
# For example, cognitive effects are not mentioned in most EPA materials.

# %%
displacy.render(nlp(str(sentences[1])), jupyter=True, style='ent')
# Out:
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# <div class="entities" style="line-height: 2.5; direction: ltr">Its adverse effects on numerous health outcomes and general mortality are widely documented.</div>

# %%
displacy.render(nlp(str(sentences[0])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2d86a210da8846dd9789812c889debd5-0" class="displacy" width="1010" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Air</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">pollution</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">very</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">big</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">deal.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2d86a210da8846dd9789812c889debd5-0-0" stroke-width="2px" d="M70,182.0 C70,122.0 160.0,122.0 160.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2d86a210da8846dd9789812c889debd5-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2d86a210da8846dd9789812c889debd5-0-1" stroke-width="2px" d="M190,182.0 C190,122.0 280.0,122.0 280.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2d86a210da8846dd9789812c889debd5-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,184.0 L182,172.0 198,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2d86a210da8846dd9789812c889debd5-0-2" stroke-width="2px" d="M310,182.0 C310,122.0 400.0,122.0 400.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2d86a210da8846dd9789812c889debd5-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,184.0 L302,172.0 318,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2d86a210da8846dd9789812c889debd5-0-3" stroke-width="2px" d="M550,182.0 C550,62.0 885.0,62.0 885.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2d86a210da8846dd9789812c889debd5-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,184.0 L542,172.0 558,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2d86a210da8846dd9789812c889debd5-0-4" stroke-width="2px" d="M670,182.0 C670,122.0 760.0,122.0 760.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2d86a210da8846dd9789812c889debd5-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,184.0 L662,172.0 678,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2d86a210da8846dd9789812c889debd5-0-5" stroke-width="2px" d="M790,182.0 C790,122.0 880.0,122.0 880.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2d86a210da8846dd9789812c889debd5-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M790,184.0 L782,172.0 798,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2d86a210da8846dd9789812c889debd5-0-6" stroke-width="2px" d="M430,182.0 C430,2.0 890.0,2.0 890.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2d86a210da8846dd9789812c889debd5-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M890.0,184.0 L898.0,172.0 882.0,172.0" fill="currentColor"/>
# </g>
# </svg>

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[0])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('\n\n', 'SPACE', '\n\n'),
#  ('Air', 'NOUN', 'air'),
#  ('pollution', 'NOUN', 'pollution'),
#  ('big', 'ADJ', 'big'),
#  ('deal', 'NOUN', 'deal')]

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[0])).ents])
# Out:
# {}

# %%
displacy.render(article, jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr"></br></br>Air pollution is a very big deal. Its adverse effects on numerous health outcomes and general mortality are widely documented. However, our understanding of its cognitive costs is more recent and those costs are almost certainly still significantly under-emphasized. For example, cognitive effects are not mentioned in most
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EPA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  materials.</br></br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World Bank
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  data indicate that
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.7 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about half
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  the world's population, are exposed to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  µg/m³ of PM2.5 on an
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     annual
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  basis,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5x
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  the unit of measure for most of the findings below.</br></br>    Chess players make more mistakes on polluted
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# : &quot;We find that an increase of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 µg/m³ raises the
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  probability of making an error by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1.5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  percentage points, and increases the magnitude of the errors by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9.4%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# . The impact of pollution is exacerbated by time pressure. When players approach the time control of games, an increase of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 µg/m³
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# , corresponding to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  standard deviation, increases the probability of making a meaningful error by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  percentage points, and errors being
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     17.3%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  larger.&quot; – Künn et al
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br>    A 3.26x (albeit with very wide
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ) increase in Alzheimer's incidence for each
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 µg/m³
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  increase in long-term PM2.5 exposure? &quot;Short- and long-term PM2.5 exposure was associated with increased risks of stroke (short-term odds ratio
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1.01
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  [per µg/m³ increase in PM2.5 concentrations],
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     95%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  CI
# <mark class="entity" style="background: #b

# %% [markdown]
# ### Mein Versuch mit deutsche Text (GR-Protokoll)

# %%
# !python -m spacy download de_core_news_sm #hier lade ich die Bibliothek
# Out:
# Requirement already satisfied: de_core_news_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-2.2.5/de_core_news_sm-2.2.5.tar.gz#egg=de_core_news_sm==2.2.5 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from de_core_news_sm==2.2.5) (2.2.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (2.0.3)
# Requirement already satisfied: numpy>=1.15.0 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (1.17.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (2.22.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (1.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (1.1.3)
# Requirement already satisfied: thinc<7.4.0,>=7.3.0 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (7.3.1)
# Requirement already satisfied: setuptools in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (41.2.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (3.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.3.0 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (0.4.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (0.23)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (0.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_sm==2.2.5) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_sm==2.2.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_sm==2.2.5) (1.25.6)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_sm==2.2.5) (2.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from thinc<7.4.0,>=7.3.0->spacy>=2.2.2->de_core_news_sm==2.2.5) (4.36.1)
# Requirement already satisfied: zipp>=0.5 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from importlib-metadata>=0.20; python_version < "3.8"->spacy>=2.2.2->de_core_news_sm==2.2.5) (0.6.0)
# Requirement already satisfied: more-itertools in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from zipp>=0.5->importlib-metadata>=0.20; python_version < "3.8"->spacy>=2.2.2->de_core_news_sm==2.2.5) (7.2.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('de_core_news_sm')

# %%
import textract
text = textract.process("DocumentLoader.pdf")

# %%
text = str(text)
text = text.encode().decode("utf-8")  #encoden muss ich es zunächst, weil es als str schon dekodiert ist (aber falsch!)
text = text.replace("\\xe2\\x80\\x93", "–")
text = text.replace("\\xc2\\xbb", "»")
text = text.replace("\\xc2\\xab", "«")
text = text.replace("\\xc3\\xb6", "ö")
text
# Out:
# 'b\'1827–1836\\n\\nSubstanzielles Protokoll 70. Sitzung\\ndes Gemeinderats von Z\\xc3\\xbcrich\\nMittwoch, 30. Oktober 2019, 21.00 Uhr bis 23.27 Uhr, im Rathaus\\n\\nVorsitz: Pr\\xc3\\xa4sident Heinz Schatt (SVP)\\nBeschlussprotokoll: Sekret\\xc3\\xa4rin Elena Marti (Gr\\xc3\\xbcne)\\nSubstanzielles Protokoll: Paulina Kerber\\nAnwesend: 119 Mitglieder\\nAbwesend: Ezgi Akyol (AL), Duri Beer (SP), Dr. David Garcia Nu\\xc3\\xb1ez (AL), Joe A. Manser (SP),\\nThomas Schwendener (SVP), Dominique Zygmont (FDP)\\n\\nDer Rat behandelt aus der vom Pr\\xc3\\xa4sidenten erlassenen, separat gedruckten Tagliste folgende\\nGesch\\xc3\\xa4fte:\\nMitteilungen\\n\\n1.\\n7.\\n\\n2019/209\\n\\nWeisung vom 22.05.2019:\\nKultur, Verein Theaterhaus Gessnerallee, Verein zur Förderung\\ndes Theaters an der Winkelwiese, Theater am Neumarkt AG,\\nNeufestsetzung Beitr\\xc3\\xa4ge ab 2019 (Erhöhung Einnahmeverzichte)\\n\\nSTP\\n\\n8.\\n\\n2019/265\\n\\nWeisung vom 19.06.2019:\\nKultur, Verein Spontankonzerte/Hombis Salon, Beitr\\xc3\\xa4ge\\n2020–2023\\n\\nSTP\\n\\n10.\\n\\n2018/425 E/A\\n\\nPostulat von Urs Helfenstein (SP) und Matthias Wiesmann\\n(GLP) vom 07.11.2018:\\nAnreicherung des Willkommenspakets der Stadt mit Informationen und Gutscheinen f\\xc3\\xbcr Kultur-, Sport- und weitere Angebote\\n\\nSTP\\n\\n11.\\n\\n2018/426 E/A\\n\\nPostulat von Corina Gredig (GLP) und Dr. Jean-Daniel Strub\\n(SP) vom 07.11.2018:\\nErg\\xc3\\xa4nzung der IT-Strategie der Stadt 2020–2024 mit der Stossrichtung 7 «Civic Tech»\\n\\nSTP\\n\\n12.\\n\\n2018/427 E/A\\n\\nPostulat von Vera Ziswiler (SP) und Michael Kraft (SP) vom\\n07.11.2018:\\nGeeignete W\\xc3\\xbcrdigung des Landesstreik-Jubil\\xc3\\xa4ums\\n\\nSTP\\n\\n13.\\n\\n2018/477 E/A\\n\\nMotion der SP- und AL-Fraktion vom 05.12.2018:\\nErhöhung des Beitrags an die Z\\xc3\\xbcrcher Filmstiftung f\\xc3\\xbcr die\\nAusrichtung von Filmpreisen\\n\\nSTP\\n\\n1\\n\\n\\x0c70. Sitzung vom 30. Oktober 2019\\n\\nMitteilungen\\n\\nEs werden keine Mitteilungen zur Kenntnis gebracht.\\n\\nGesch\\xc3\\xa4fte\\n\\n1827.\\n\\n2019/209\\nWeisung vom 22.05.2019:\\nKultur, Verein Theaterhaus Gessnerallee, Verein zur Förderung des Theaters an\\nder Winkelwiese, Theater am Neumarkt AG, Neufestsetzung Beitr\\xc3\\xa4ge ab 2019\\n(Erhöhung Einnahmeverzichte)\\nAusstand: Dr. Ann-Catherine Nabholz (GLP)\\nAntrag des Stadtrats\\n1.\\n\\n2.\\n\\n3.\\n\\nF\\xc3\\xbcr den Verein Theaterhaus Gessnerallee wird in Ab\\xc3\\xa4nderung von Dispositiv-Ziffer 2\\ndes Gemeinderatsbeschlusses vom 7. Dezember 2011 (GR Nr. 2011/283) f\\xc3\\xbcr die\\nR\\xc3\\xa4umlichkeiten in der Liegenschaft Gessnerallee 8/8a ab 2019 die \\xc3\\x9cbernahme der\\num Fr. 88 092.– erhöhten Mietkosten von bisher Fr. 1 109 568.– auf neu\\nFr. 1 197 660.– bewilligt. In Ab\\xc3\\xa4nderung von Dispositiv-Ziffer 1 des Gemeinderatsbeschlusses vom 7. Dezember 2011 wird der Betriebsbeitrag um Fr. 176 000.– auf\\nFr. 2 136 693.– gek\\xc3\\xbcrzt. Insgesamt wird damit ab 2019 ein j\\xc3\\xa4hrlich wiederkehrender\\nGesamtbeitrag f\\xc3\\xbcr das Theaterhaus Gessnerallee von neu Fr. 3 334 353.– (ohne allf\\xc3\\xa4llige Teuerungsanpassung ab 2020) bewilligt.\\nDer Stadtrat wird erm\\xc3\\xa4chtigt, den Betrag f\\xc3\\xbcr den Mieterlass f\\xc3\\xbcr den Verein Theaterhaus Gessnerallee anzupassen, sofern sich eine solche Anpassung allein aufgrund\\neiner \\xc3\\x84nderung der intern verrechneten Miete gem\\xc3\\xa4ss Stadtratsbeschluss\\nNr. 1058/2018 ergibt und nicht durch einen höheren Fl\\xc3\\xa4chenbedarf der Suventionsnehmer ausgelöst wird.\\nF\\xc3\\xbcr den Verein zur Förderung des Theaters an der Winkelwiese wird f\\xc3\\xbcr die R\\xc3\\xa4umlichkeiten in der Liegenschaft Werdinsel 2 f\\xc3\\xbcr das Jahr 2019 die \\xc3\\x9cbernahme der um\\nFr. 36 285.– erhöhten Mietkosten von bisher Fr. 11 011.– auf neu Fr. 47 296.– bewilligt. In Ab\\xc3\\xa4nderung von Dispositiv-Ziffer 1 des Gemeinderatsbeschlusses vom\\n25. November 2015 (GR Nr. 2015/208) wird der Betriebsbeitrag 20 ...

# %% [markdown]
# Der Decode-Befehl oben sollte das gleiche machen, wie wenn ich das hier manuell eingeben würde:
#
# - text = text.replace("\\n\\n", " ")
# - text = text.replace("\\n", " ")
# - text = text.replace("\\xc3\\xbc", "ü")
# - text = text.replace("\\xc3\\xa4", "ä")
# - text = text.replace("\\xc3\\xab", "ë")
# - etc.

# %%
import spacy
from spacy import displacy
from collections import Counter
import de_core_news_sm    #hier...
nlp = de_core_news_sm.load()   #... und hier lädt spacy einen Datensatz runter, um damit zu trainieren

# %%
text = nlp(text)
len(text.ents) #Anzahl der Entitäten
# Out:
# 1431

# %%
labels = [x.label_ for x in text.ents]
Counter(labels)
# Out:
# Counter({'ORG': 366, 'MISC': 615, 'PER': 223, 'LOC': 227})

# %%
displacy.render(text, jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     b'1827–1836\n\nSubstanzielles Protokoll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  70. Sitzung\ndes Gemeinderats von Z\xc3\xbcrich\nMittwoch, 30. Oktober 2019, 21.00 Uhr bis 23.27 Uhr, im
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rathaus\n\nVorsitz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# :
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pr\xc3\xa4sident Heinz Schatt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SVP)\nBeschlussprotokoll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# : Sekret\xc3\xa4rin
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elena Marti
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (Gr\xc3\xbcne)\nSubstanzielles Protokoll:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paulina Kerber\nAnwesend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# : 119 Mitglieder\nAbwesend:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ezgi Akyol
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ),
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Duri Beer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), Dr.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     David Garcia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  Nu\xc3\xb1ez (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ),
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe A. Manser
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SP),\nThomas Schwendener
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SVP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ),
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dominique Zygmont
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FDP)\n\nDer Rat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  behandelt aus der vom Pr\xc3\xa4sidenten erlassenen, separat gedruckten Tagliste folgende\nGesch\xc3\xa4fte:\nMitteilungen\n\n1.\n7.\n\n2019/209\n\nWeisung vom 22.05.2019:\nKultur, Verein
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Theaterhaus Gessnerallee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , Verein zur
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Förderung\ndes Theaters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  an der
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Winkelwiese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Theater am Neumarkt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  AG,\nNeufestsetzung Beitr\xc3\xa4ge ab 2019 (Erhöhung Einnahmeverzichte)\n\nSTP\n\n8.\n\n2019/265\n\nWeisung vom 19.06.2019:\nKultur, Verein
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spontankonzerte/Hombis Salon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align:

# %%
for entity in text.ents:
    if entity.label_ == "ORG":
        print(entity, entity.label_)
# Out:
# b'1827–1836\n\nSubstanzielles Protokoll ORG
# Pr\xc3\xa4sident Heinz Schatt ORG
# AL ORG
# Duri Beer ORG
# SP ORG
# AL ORG
# SVP ORG
# Spontankonzerte/Hombis Salon ORG
# SP ORG
# GLP ORG
# GLP ORG
# SP ORG
# SP ORG
# SP ORG
# Landesstreik-Jubil\xc3\xa4ums\n\nSTP\n\n13.\n\n2018/477 ORG
# AL-Fraktion ORG
# Theaterhaus Gessnerallee ORG
# Winkelwiese ORG
# neu\nFr ORG
# Theaterhaus Gessnerallee ORG
# Winkelwiese ORG
# um\nFr ORG
# Theater Neumarkt AG ORG
# Dispositiv-Ziffer ORG
# j\xc3\xa4hrlich ORG
# neu\nFr ORG
# Theater Neumarkt AG ORG
# erm\xc3\xa4chtigt ORG
# wird.\n4.\n\nDie ORG
# Winkelwiese ORG
# selbstst\xc3\xa4ndig ORG
# SP ORG
# Schlussabstimmungen:\nStefan Urech ORG
# SVP ORG
# IMMO ORG
# Dispositivziffer ORG
# Theaterhaus Gessnerallee ORG
# neu\nFr ORG
# Theaterhaus Gessnerallee ORG
# SP ORG
# SVP ORG
# Roger\nBartholdi ORG
# SVP ORG
# Yasmine Bourgeois ORG
# FDP ORG
# GLP ORG
# FDP ORG
# SP ORG
# SP ORG
# SP ORG
# SK PRD/SSD ORG
# Theater Neumarkt AG ORG
# Dispositiv-Ziffer ORG
# neu\nFr ORG
# Theater Neumarkt AG ORG
# erm\xc3\xa4chtigt ORG
# SP ORG
# SVP ORG
# Roger\nBartholdi ORG
# SVP ORG
# Yasmine Bourgeois ORG
# FDP ORG
# GLP ORG
# FDP ORG
# SP ORG
# SP ORG
# SP ORG
# SK PRD/SSD ORG
# SP ORG
# Yasmine\nBourgeois ORG
# FDP ORG
# GLP ORG
# FDP ORG
# SP ORG
# AL ORG
# SP ORG
# SVP ORG
# SP ORG
# Yasmine\nBourgeois ORG
# FDP ORG
# GLP ORG
# FDP ORG
# SP ORG
# AL ORG
# SP ORG
# SVP ORG
# SP ORG
# Yasmine\nBourgeois ORG
# FDP ORG
# GLP ORG
# FDP ORG
# SP ORG
# AL ORG
# SP ORG
# SVP ORG
# SP ORG
# Yasmine\nBourgeois ORG
# FDP ORG
# GLP ORG
# FDP ORG
# SP ORG
# AL ORG
# SP ORG
# SVP ORG
# SP ORG
# Yasmine\nBourgeois ORG
# FDP ORG
# GLP ORG
# FDP ORG
# SP ORG
# AL ORG
# SP ORG
# SVP ORG
# Theaterhaus Gessnerallee ORG
# neu\nFr ORG
# Theaterhaus Gessnerallee ORG
# um\nFr ORG
# Theater Neumarkt AG ORG
# Dispositiv-Ziffer ORG
# j\xc3\xa4hrlich ORG
# neu\nFr ORG
# Theater Neumarkt AG ORG
# Spontankonzerte/Hombis Salon ORG
# Spontankonzerte/Hombis Salon ORG
# \xc3\xbcber ORG
# SP ORG
# \xc3\x9cberbauung ORG
# Tr\xc3\xa4gerschaft\nVerein ORG
# Essens ORG
# Spontankonzerte ORG
# \xc3\xbcber ORG
# Z\xc3\xbcrich\nNord ORG
# Kommission ORG
# Teilhabe st\xc3\xa4rken ORG
# Diversit\xc3\xa4t ORG
# Kommission ORG
# Schlussabstimmung:\nStefan Urech ORG
# SVP ORG
# Kulturh\xc3\xa4usern ORG
# kleine\nBetr\xc3\xa4ge ORG
# SP ORG
# SP ORG
# AL ORG
# AL ORG
# nicht.\nChristian Huser ORG
# FDP ORG
# FDP ORG
# AL ORG
# Spontankonzerte/Hombis Salon ORG
# SVP ORG
# SVP ORG
# FDP ORG
# GLP ORG
# SP ORG
# SP ORG
# SP ORG
# SP ORG
# SP ORG
# FDP ORG
# GLP ORG
# GLP),\nChristian Huser ORG
# FDP ORG
# SP ORG
# AL ORG
# SVP ORG
# SP ORG
# SP ORG
# Vizepr\xc3\xa4sident Stefan\nUrech ORG
# SVP ORG
# SVP ORG
# FDP ORG
# GLP),\nSimone Hofer Frei ORG
# GLP ORG
# FDP ORG
# SP ORG
# AL ORG
# SP ORG
# SP ORG
# FDP ORG
# GLP ORG
# GLP),\nChristian Huser ORG
# FDP ORG
# SP ORG
# AL ORG
# SVP ORG
# Spontankonzerte/Hombis Salon ORG
# \xc3\xbcber ORG
# SP ORG
# GLP ORG
# SP ORG
# SVP ORG
# SVP ORG
# Gratistickets ORG
# Smart City ORG
# der\n13\n\n\x0c70 ORG
# wir\npr\xc3\xbcfen ORG
# FDP ORG
# FDP ORG
# SVP ORG
# FDP ORG
# GLP ORG
# SP ORG
# Civic\nTech»\nGem\xc3\xa4ss schriftlicher Mitteilung ORG
# SP ORG
# GLP ORG
# st\xc3\xa4rken ORG
# wir\nein Gemeinwesen ORG
# Dies\nist ORG
# IT-Strategie ORG
# erg\xc3\xa4nzen ORG
# SVP ORG
# SVP ORG
# SP ORG
# Daf\xc3\xbcr ORG
# bew\xc3\xa4hrten ORG
# Wortmeldungen:\nYasmine Bourgeois ORG
# FDP ORG
# FDP ORG
# gegen\xc3\xbcber ORG
# Vorstellungen\neiner digitalen Gesellschaft ORG
# Bund ORG
# FDP ORG
# EU ORG
# Civic Tech ORG
# AL ORG
# Civic Tech ORG
# SP ORG
# IT-Strategie ORG
# GLP ORG
# Smart City Strategie ORG
# IT-Bereich ORG
# GLP ORG
# Partei ORG
# IT-Bereich ORG
# SVP ORG
# IT-Strategie ORG
# EVP ORG
# SP ORG
# AL ORG
# Smart City Strategie ORG
# budgeting\xe2\x80\x99 ORG
# AL ORG
# SVP ORG
# SVP ORG
# \xc3\xbcber ORG
# haben.\nSusanne Brunner ORG
# SVP ORG
# SP ORG
# gegen\xc3\xbcber ORG
# Partei ORG
# bew\xc3\xa4hrten ORG
# SVP ORG
# EU ORG
# EU ORG
# sprechen.\nIsabel Garcia ORG
# GLP ORG
# irgendeine Partei ORG
# SP ORG
# SP ORG
# Landesstreik-Jubil\xc3\xa4ums\nGem\xc3\xa4ss ORG
# entgegenzunehmen.\nMichael Kraft ORG
# SP ORG
# Aktualit\xc3\xa4t ORG
# beschr\xc3\xa4nken ORG
# Daf\xc3\xbcr w\xc3\xa4re ORG
# AHV ORG
# Impuls ORG
# Die\nSchweizer Armee ORG
# Identit\xc3\xa4 ORG
# SVP ORG
# SVP ORG
# SVP-Fraktion ORG
# Bund beauftragen,\nein Denkmal ORG
# legitim ORG
# Oltener Aktionskomitees ORG
# Armee ORG
# Komitees zu Gef\xc3\xa4ngnisstrafen ORG
# Gesellschaft wach ORG
# FDP ORG
# Nachdem\nes ORG
# SP ORG
# FDP ORG
# FDP ORG
# FDP ORG
# Sozialdemokraten ORG
# FDP ORG
# FDP ORG
# FDP ORG
# Arbeiter\n\n20\n\n\x0c70 ORG
# FDP ORG
# FDP ORG
# GLP ORG
# FDP ORG
# FDP ORG
# SVP ORG
# Schweiz\ndurch radikale Sozialisten ORG
# b\xc3\xbcrgerlichen Gesellschaft ORG
# nicht\n\xc3\xbcber ORG
# Sowjetunion ORG
# Sowjetunion ORG
# wollten.\nChristoph Marty ORG
# SVP ORG
# Z\xc3\xbcrcher SP ORG
# Gewerkschaft ORG
# VPOD ORG
# Gewerkschaften ORG
# Gewerkschaften ORG
# Gewerkschaften ORG
# SVP ORG
# Liberalen ORG
# FDP ORG
# FDP ORG
# FDP ORG
# SVP ORG
# SVP ORG
# FDPDominanz ORG
# EVP ORG
# Zeit habe,\nweiss ORG
# SP-Mitglied ORG
# Gewerkschafter ORG
# EVP ORG
# SVP ORG
# SP-Seite ORG
# SVP ORG
# kommunistische\nChina ORG
# Sowjetunion ORG
# Sowjetunion ORG
# B\xc3\xbcrgerkriegstreiber,\ndie ORG
# st\xc3\xbcrzen ORG
# Sowjetunion ORG
# SP- ORG
# AL-Fraktion ORG
# AL ORG
# Filmtechnikern ORG
# PRD ORG
# naturgem\xc3\xa4ss ORG
# \xc3\xbcber ORG
# SVP ORG
# SVP ORG
# SVP-Fraktion ORG
# st\xc3\xa4rken ORG
# AL ORG
# FDP ORG
# SVP ORG
# SVP ORG
# SVP ORG
# SVP ORG
# Stadtrat\n1834 ORG
# AL ORG
# EVP ORG
# AL ORG
# EVP ORG
# SP ORG
# Kraftwerke Oberhasli AG ORG
# Strategie der\nStadt ORG
# Kraftwerken Oberhasli AG ORG
# SP ORG
# einem\nSechstel Aktion\xc3\xa4rin ORG
# KWO ORG
# ewz ORG
# KWO ORG
# KWO ORG
# Wasserzinses?\nIst ORG
# Stadtrat\n1836 ORG
# SP ORG
# SP ORG

# %%
#so lasse ich mir die erwähnten Organisationen aufzählen (alle nur 1x, das macht "set")

organisationen = []

for entity in text.ents:
    if entity.label_ == "ORG":
        organisationen.append(str(entity))

set(organisationen)
# Out:
# {'AHV',
#  'AL',
#  'AL-Fraktion',
#  'Aktualit\\xc3\\xa4t',
#  'Arbeiter\\n\\n20\\n\\n\\x0c70',
#  'Armee',
#  'B\\xc3\\xbcrgerkriegstreiber,\\ndie',
#  'Bund',
#  'Bund beauftragen,\\nein Denkmal',
#  'Civic Tech',
#  'Civic\\nTech»\\nGem\\xc3\\xa4ss schriftlicher Mitteilung',
#  'Daf\\xc3\\xbcr',
#  'Daf\\xc3\\xbcr w\\xc3\\xa4re',
#  'Die\\nSchweizer Armee',
#  'Dies\\nist',
#  'Dispositiv-Ziffer',
#  'Dispositivziffer',
#  'Diversit\\xc3\\xa4t',
#  'Duri Beer',
#  'EU',
#  'EVP',
#  'Essens',
#  'FDP',
#  'FDPDominanz',
#  'Filmtechnikern',
#  'GLP',
#  'GLP),\\nChristian Huser',
#  'GLP),\\nSimone Hofer Frei',
#  'Gesellschaft wach',
#  'Gewerkschaft',
#  'Gewerkschaften',
#  'Gewerkschafter',
#  'Gratistickets',
#  'IMMO',
#  'IT-Bereich',
#  'IT-Strategie',
#  'Identit\\xc3\\xa4',
#  'Impuls',
#  'KWO',
#  'Komitees zu Gef\\xc3\\xa4ngnisstrafen',
#  'Kommission',
#  'Kraftwerke Oberhasli AG',
#  'Kraftwerken Oberhasli AG',
#  'Kulturh\\xc3\\xa4usern',
#  'Landesstreik-Jubil\\xc3\\xa4ums\\nGem\\xc3\\xa4ss',
#  'Landesstreik-Jubil\\xc3\\xa4ums\\n\\nSTP\\n\\n13.\\n\\n2018/477',
#  'Liberalen',
#  'Nachdem\\nes',
#  'Oltener Aktionskomitees',
#  'PRD',
#  'Partei',
#  'Pr\\xc3\\xa4sident Heinz Schatt',
#  'Roger\\nBartholdi',
#  'SK PRD/SSD',
#  'SP',
#  'SP-',
#  'SP-Mitglied',
#  'SP-Seite',
#  'SVP',
#  'SVP-Fraktion',
#  'Schlussabstimmung:\\nStefan Urech',
#  'Schlussabstimmungen:\\nStefan Urech',
#  'Schweiz\\ndurch radikale Sozialisten',
#  'Smart City',
#  'Smart City Strategie',
#  'Sowjetunion',
#  'Sozialdemokraten',
#  'Spontankonzerte',
#  'Spontankonzerte/Hombis Salon',
#  'Stadtrat\\n1834',
#  'Stadtrat\\n1836',
#  'Strategie der\\nStadt',
#  'Teilhabe st\\xc3\\xa4rken',
#  'Theater Neumarkt AG',
#  'Theaterhaus Gessnerallee',
#  'Tr\\xc3\\xa4gerschaft\\nVerein',
#  'VPOD',
#  'Vizepr\\xc3\\xa4sident Stefan\\nUrech',
#  'Vorstellungen\\neiner digitalen Gesellschaft',
#  'Wasserzinses?\\nIst',
#  'Winkelwiese',
#  'Wortmeldungen:\\nYasmine Bourgeois',
#  'Yasmine Bourgeois',
#  'Yasmine\\nBourgeois',
#  'Z\\xc3\\xbcrcher SP',
#  'Z\\xc3\\xbcrich\\nNord',
#  'Zeit habe,\\nweiss',
#  '\\xc3\\x9cberbauung',
#  '\\xc3\\xbcber',
#  "b'1827–1836\\n\\nSubstanzielles Protokoll",
#  'b\\xc3\\xbcrgerlichen Gesellschaft',
#  'beschr\\xc3\\xa4nken',
#  'bew\\xc3\\xa4hrten',
#  'budgeting\\xe2\\x80\\x99',
#  'der\\n13\\n\\n\\x0c70',
#  'einem\\nSechstel Aktion\\xc3\\xa4rin',
#  'entgegenzunehmen.\\nMichael Kraft',
#  'erg\\xc3\\xa4nzen',
#  'erm\\xc3\\xa4chtigt',
#  'ewz',
#  'gegen\\xc3\\xbcber',
#  'haben.\\nSusanne Brunner',
#  'irgendeine Partei',
#  'j\\xc3\\xa4hrlich',
#  'kleine\\nBetr\\xc3\\xa4ge',
#  'kommunistische\\nChina',
#  'legitim',
#  'naturgem\\xc3\\xa4ss',
#  'neu\\nFr',
#  'nicht.\\nChristian Huser',
#  'nicht\\n\\xc3\\xbcber',
#  'selbstst\\xc3\\xa4ndig',
#  'sprechen.\\nIsabel Garcia',
#  'st\\xc3\\xa4rken',
#  'st\\xc3\\xbcrzen',
#  'um\\nFr',
#  'wir\\nein Gemeinwesen',
#  'wir\\npr\\xc3\\xbcfen',
#  'wird.\\n4.\\n\\nDie',
#  'wollten.\\nChristoph Marty'}

# %%
from collections import Counter

organisationen = []

for entity in text.ents:
    if entity.label_ == "ORG":
        organisationen.append(str(entity))

Counter(organisationen)

import pandas as pd
anzahl = (Counter(organisationen))
          
df = pd.DataFrame(dict(anzahl), index=["Nennungen"])
df_transposed = df.T
df_transposed.sort_values("Nennungen", ascending = False).head(6)
# Out:
#                           Nennungen
# SP                               60
# FDP                              44
# SVP                              43
# AL                               20
# GLP                              20
# Theaterhaus Gessnerallee          6

# %%
from collections import Counter

organisationen = []

for entity in text.ents:
    if entity.label_ == "PER":
        organisationen.append(str(entity))

Counter(organisationen)

import pandas as pd
anzahl = (Counter(organisationen))
          
df = pd.DataFrame(dict(anzahl), index=["Nennungen"])
df_transposed = df.T
df_transposed.sort_values("Nennungen", ascending = False).head(10)
# Out:
#                      Nennungen
# Jean-Daniel Strub           19
# Ursula N\xc3\xa4f           11
# Christoph Homberger         11
# Roger Bartholdi              9
# Isabel Garcia                8
# Patrik Maillard              8
# Mark Richli                  8
# Hombis Salon                 6
# \xc3\xbcber                  6
# Christian Huser\n            5

# %% [markdown]
# ### Das gleiche mit einer grösseren Bibliothek zum Trainieren

# %%
#!python -m spacy download de_core_news_md
# Out:
# Collecting de_core_news_md==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_md-2.2.5/de_core_news_md-2.2.5.tar.gz (224.6MB)
#      |████████████████████████████████| 224.6MB 3.3MB/s eta 0:00:014   |█████████████▎                  | 92.8MB 4.3MB/s eta 0:00:31| 157.1MB 4.6MB/s eta 0:00:15     |██████████████████████▍         | 157.4MB 2.0MB/s eta 0:00:34�██▋        | 165.9MB 4.1MB/s eta 0:00:15     |███████████████████████▊        | 166.2MB 4.1MB/s eta 0:00:15     |████████████████████████▌       | 172.0MB 1.2MB/s eta 0:00:45     |████████████████████████▉       | 174.1MB 14.4MB/s eta 0:00:04     |███████████████████████████▋    | 193.6MB 2.1MB/s eta 0:00:15     |███████████████████████████▊    | 194.7MB 2.1MB/s eta 0:00:14     |██████████████████████████████▎ | 212.2MB 2.2MB/s eta 0:00:06     |██████████████████████████████▉ | 216.3MB 3.7MB/s eta 0:00:03     |██████████████████████████████▉ | 216.7MB 3.7MB/s eta 0:00:03
# Requirement already satisfied: spacy>=2.2.2 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from de_core_news_md==2.2.5) (2.2.2)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_md==2.2.5) (0.2.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_md==2.2.5) (0.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_md==2.2.5) (3.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_md==2.2.5) (1.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_md==2.2.5) (1.17.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.3.0 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_md==2.2.5) (0.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_md==2.2.5) (2.22.0)
# Requirement already satisfied: thinc<7.4.0,>=7.3.0 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_md==2.2.5) (7.3.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_md==2.2.5) (2.0.3)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_md==2.2.5) (0.23)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_md==2.2.5) (1.1.3)
# Requirement already satisfied: setuptools in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from spacy>=2.2.2->de_core_news_md==2.2.5) (41.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_md==2.2.5) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_md==2.2.5) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_md==2.2.5) (1.25.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_md==2.2.5) (3.0.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from thinc<7.4.0,>=7.3.0->spacy>=2.2.2->de_core_news_md==2.2.5) (4.36.1)
# Requirement already satisfied: zipp>=0.5 in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from importlib-metadata>=0.20; python_version < "3.8"->spacy>=2.2.2->de_core_news_md==2.2.5) (0.6.0)
# Requirement already satisfied: more-itertools in /Users/Datenjournalismus/.virtualenvs/erstesVE/lib/python3.7/site-packages (from zipp>=0.5->importlib-metadata>=0.20; python_version < "3.8"->spacy>=2.2.2->de_core_news_md==2.2.5) (7.2.0)
# Building wheels for collected packages: de-core-news-md
#   Building wheel for de-core-news-md (setup.py) ... done
#   Created wheel for de-core-news-md: filename=de_core_news_md-2.2.5-cp37-none-any.whl size=228399478 sha256=c34a4d5f7eba8b52a5f29d38f612b6f1dc1dd7e7ab64259b09fb6643c0b587e2
#   Stored in directory: /private/var/folders/lf/x9vwljj10y5627m1l17chjdm0000gr/T/pip-ephem-wheel-cache-dujr8go0/wheels/41/60/41/81898870259d7c19fe8f9e46a537611c939f0c425eee2e1785
# Successfully built de-core-news-md
# Installing collected packages: de-core-news-md
# Successfully installed de-core-news-md-2.2.5
# ✔ Download and installation successful
# You can now load the model via spacy.load('de_core_news_md')

# %%
import spacy
from spacy import displacy

import pandas as pd

from collections import Counter

import de_core_news_md    #Hier md statt sm – dauert entsprechend, weil gross!
nlp = de_core_news_md.load()

# %%
text = textract.process("DocumentLoader.pdf").decode("utf-8")
text = text.replace("\n", " ")
text
# Out:
# '1827–1836  Substanzielles Protokoll 70. Sitzung des Gemeinderats von Zürich Mittwoch, 30. Oktober 2019, 21.00 Uhr bis 23.27 Uhr, im Rathaus  Vorsitz: Präsident Heinz Schatt (SVP) Beschlussprotokoll: Sekretärin Elena Marti (Grüne) Substanzielles Protokoll: Paulina Kerber Anwesend: 119 Mitglieder Abwesend: Ezgi Akyol (AL), Duri Beer (SP), Dr. David Garcia Nuñez (AL), Joe A. Manser (SP), Thomas Schwendener (SVP), Dominique Zygmont (FDP)  Der Rat behandelt aus der vom Präsidenten erlassenen, separat gedruckten Tagliste folgende Geschäfte: Mitteilungen  1. 7.  2019/209  Weisung vom 22.05.2019: Kultur, Verein Theaterhaus Gessnerallee, Verein zur Förderung des Theaters an der Winkelwiese, Theater am Neumarkt AG, Neufestsetzung Beiträge ab 2019 (Erhöhung Einnahmeverzichte)  STP  8.  2019/265  Weisung vom 19.06.2019: Kultur, Verein Spontankonzerte/Hombis Salon, Beiträge 2020–2023  STP  10.  2018/425 E/A  Postulat von Urs Helfenstein (SP) und Matthias Wiesmann (GLP) vom 07.11.2018: Anreicherung des Willkommenspakets der Stadt mit Informationen und Gutscheinen für Kultur-, Sport- und weitere Angebote  STP  11.  2018/426 E/A  Postulat von Corina Gredig (GLP) und Dr. Jean-Daniel Strub (SP) vom 07.11.2018: Ergänzung der IT-Strategie der Stadt 2020–2024 mit der Stossrichtung 7 «Civic Tech»  STP  12.  2018/427 E/A  Postulat von Vera Ziswiler (SP) und Michael Kraft (SP) vom 07.11.2018: Geeignete Würdigung des Landesstreik-Jubiläums  STP  13.  2018/477 E/A  Motion der SP- und AL-Fraktion vom 05.12.2018: Erhöhung des Beitrags an die Zürcher Filmstiftung für die Ausrichtung von Filmpreisen  STP  1  \x0c70. Sitzung vom 30. Oktober 2019  Mitteilungen  Es werden keine Mitteilungen zur Kenntnis gebracht.  Geschäfte  1827.  2019/209 Weisung vom 22.05.2019: Kultur, Verein Theaterhaus Gessnerallee, Verein zur Förderung des Theaters an der Winkelwiese, Theater am Neumarkt AG, Neufestsetzung Beiträge ab 2019 (Erhöhung Einnahmeverzichte) Ausstand: Dr. Ann-Catherine Nabholz (GLP) Antrag des Stadtrats 1.  2.  3.  Für den Verein Theaterhaus Gessnerallee wird in Abänderung von Dispositiv-Ziffer 2 des Gemeinderatsbeschlusses vom 7. Dezember 2011 (GR Nr. 2011/283) für die Räumlichkeiten in der Liegenschaft Gessnerallee 8/8a ab 2019 die Übernahme der um Fr. 88 092.– erhöhten Mietkosten von bisher Fr. 1 109 568.– auf neu Fr. 1 197 660.– bewilligt. In Abänderung von Dispositiv-Ziffer 1 des Gemeinderatsbeschlusses vom 7. Dezember 2011 wird der Betriebsbeitrag um Fr. 176 000.– auf Fr. 2 136 693.– gekürzt. Insgesamt wird damit ab 2019 ein jährlich wiederkehrender Gesamtbeitrag für das Theaterhaus Gessnerallee von neu Fr. 3 334 353.– (ohne allfällige Teuerungsanpassung ab 2020) bewilligt. Der Stadtrat wird ermächtigt, den Betrag für den Mieterlass für den Verein Theaterhaus Gessnerallee anzupassen, sofern sich eine solche Anpassung allein aufgrund einer Änderung der intern verrechneten Miete gemäss Stadtratsbeschluss Nr. 1058/2018 ergibt und nicht durch einen höheren Flächenbedarf der Suventionsnehmer ausgelöst wird. Für den Verein zur Förderung des Theaters an der Winkelwiese wird für die Räumlichkeiten in der Liegenschaft Werdinsel 2 für das Jahr 2019 die Übernahme der um Fr. 36 285.– erhöhten Mietkosten von bisher Fr. 11 011.– auf neu Fr. 47 296.– bewilligt. In Abänderung von Dispositiv-Ziffer 1 des Gemeinderatsbeschlusses vom 25. November 2015 (GR Nr. 2015/208) wird der Betriebsbeitrag 2019 um Fr. 11 011.– von bisher Fr. 724 500.– auf neu Fr. 713 489.– gekürzt. Für das Jahr 2019 wird damit ein Gesamtbeitrag für das Theater an der Winkelwiese von Fr. 760 785.– bewilligt. Für die Theater Neumarkt AG wird für die Räumlichkeiten in den Liegenschaften Werdinsel 2, 3 & 4 und Neumarkt 5 ab 2019 die Übernahme der um Fr. 579 188.– erhöhten Mietkosten von bisher Fr. 112 881.– (Fr. 84 156.– plus Fr. 5 490.– plus Fr. 23 235.–) auf neu Fr. 692 069.– (Fr. 377 283.– plus Fr. 314 786.–) bewilligt. In Abänderung von Dispositiv-Ziffer 7 STRB Nr. 339/2017 wird der jährlich wiederkeh ...

# %%
text = nlp(text)
len(text.ents)
# Out:
# 1219

# %%
organisationen = []

for entity in text.ents:
    if entity.label_ == "LOC":
        organisationen.append(str(entity))

Counter(organisationen)


anzahl = (Counter(organisationen))
          
df = pd.DataFrame(dict(anzahl), index=["Nennungen"])
df_transposed = df.T
df_transposed.sort_values("Nennungen", ascending = False).head(10)
# Out:
#                           Nennungen
# Zürich                           38
# Stadt                            25
# Schweiz                          19
# Stadt Zürich                     16
# Oerlikon                         11
# der Schweiz                      10
# Wipkingen                         8
# Dispositiv-Ziffer                 8
# Theaterhaus Gessnerallee          6
# Landesmuseum                      6
